# %% [markdown]
# # NUTNRB Checker
#
# This notebook is designed to check the NUTNR csv calibration file in pull request. The process I follow is:
# 1. Read in the NUTNR csv from the pull request into a pandas dataframe
# 2. Identify the source file of the calibration coefficients
# 3. Parse the calibration coefficients directly from the source file
# 4. Compare the NUTNR csv from the pull request with the csv parsed from the source file
#
# **====================================================================================================================**
#
# The first step is to load relevant packages:

# %%
import csv
import re
import os
import shutil
import numpy as np
import pandas as pd

# %%
from utils import *

# %%
from zipfile import ZipFile
import string

# %% [markdown]
# **====================================================================================================================**
# Define the directories where the **csv** file to check is stored, and where the **source** file is stored. Make sure to check the following information on your machine via your terminal first:
# 1. The branch of your local asset-management repository matches the location of the OPTAA cals.
# 2. Your local asset-management repository has the requisite **csv** file to check
# 3. You have downloaded the **source** of the csv file

# %%
doc_directory = '/media/andrew/OS/Users/areed/Documents/Project_Files/Records/Instrument_Records/NUTNR/NUTNR_Results/'
cal_directory = '/media/andrew/OS/Users/areed/Documents/Project_Files/Records/Instrument_Records/NUTNR/NUTNR_Cal/'
asset_management_directory = '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/NUTNRB/'
glider_directory = '/media/andrew/OS/Users/areed/Documents/Project_Files/Records/Platform_Records/Gliders/Instruments/NUTNR-M/'

# %%
os.listdir(glider_directory)
# Out:
# ['NUTNR-M_SUNA_SN_657_Calibration_Files_2015-07-13.zip',
#  'NUTNR-M_SUNA_SN_658_Calibration_Files_2015-07-29.zip',
#  'NUTNR-M_SUNA_SN_659_Calibration_Files_2015-07-29.zip',
#  'NUTNR-M_SUNA_SN_660_Calibration_Files_2015-07-29.zip',
#  'NUTNR-M_SUNA_SN_661_Calibration_Files_2015-07-29.zip',
#  'NUTNR-M_SUNA_SN_662_Calibration_Files_2015-07-23.zip',
#  'NUTNR-M_SUNA_SN_708_Calibration_Files_2015-09-24.zip',
#  'NUTNR-M_SUNA_SN_709_Calibration_Files_2015-09-22.zip',
#  'NUTNR-M_SUNA_SN_710_Calibration_Files_2015-09-28.zip',
#  'NUTNR-M_SUNA_SN_711_Calibration_Files_2015-09-23.zip',
#  'NUTNR-M_SUNA_SN_727_Calibration_Files_2015-10-14.zip',
#  'NUTNR-M_SUNA_SN_729_Calibration_Files_2015-10-13.zip',
#  'NUTNR-M_SUNA_SN_730_Calibration_Files_2015-10-08.zip',
#  '_V']

# %%
excel_spreadsheet = '/media/andrew/OS/Users/areed/Documents/Project_Files/Documentation/System/System Notebook/WHOI_Asset_Tracking.xlsx'
sheet_name = 'Sensors'

# %%
NUTNR = whoi_asset_tracking(spreadsheet=excel_spreadsheet,sheet_name=sheet_name,instrument_class='NUTNR',series='B')
NUTNR
# Out:
#     Instrument\nClass Series Supplier\nSerial Number  WHOI #   OOI #  \
# 876             NUTNR      B                     239  115084  A00065
# 877             NUTNR      B                     240  115085  A00066
# 878             NUTNR      B                     260  115671  A00383
# 879             NUTNR      B                     261  115672  A00384
# 880             NUTNR      B                     262  115673  A00385
# 881             NUTNR      B                     266  116564  A00880
# 894  ...                 3305-00108-00033\n3305-00108-00055
# 895  ...                 3305-00108-00034\n3305-00108-00057
# 896  ...                 3305-00108-00035\n3305-00108-00063
# 916  ...                                   3305-00127-00007
# 917  ...                 3305-00127-00008\n3305-00127-00037
# 918  ...                 3305-00127-00009\n3305-00127-00035
# 919  ...                 3305-00127-00010\n3305-00127-00036
# 920  ...                                   3305-00127-00019
# 921  ...                                   3305-00127-00014
# 922  ...                                   3305-00127-00012
# 923  ...                                   3305-00127-00018
# 924  ...                                   3305-00127-00016
# 925  ...                                   3305-00127-00017
# 926  ...                                   3305-00127-00015
# 927  ...                                   3305-00127-00013
# 928  ...                                   3305-00127-00011
# 929  ...                                   3305-00127-00022
# 930  ...                                   3305-00127-00023
# 931  ...                                   3305-00127-00020
# 932  ...                                   3305-00127-00021
#
#                                          PreDeployment  \
# 876                                   3305-00308-00001
# 877                                                NaN
# 878                                                NaN
# 879  3305-00308-00007\n3305-00308-00031\n3305-00308...
# 880                                   3305-00308-00002
# 881                 3305-00308-00004\n3305-00308-00032
# 882                                                NaN
# 883                 3305-00308-00003\n3305-00308-00034
# 884                 3305-00308-00005\n3305-00308-00009
# 885                 3305-00308-00006\n3305-00308-00008
# 886                 3305-00308-00010\n3305-00308-00062
# 887                                   3305-00308-00047
# 888                                   3305-00308-00066
# 889  3305-00308-00011\n3305-00308-00012\n3305-00308...
# 890                                                NaN
# 891                                   3305-00308-00065
# 892                                                NaN
# 893                                   3305-00308-00014
# 894                 3305-00308-00012\n3305-00308-00048
# 895                                   3305-00308-00013
# 896                 3305-00308-00033\n3305-00308-00067
# 916                                                NaN
# 917                                                NaN
# 918                                                NaN
# 919                                                NaN
# 920                                   3305-00327-00036
# 921                                   3305-00327-00037
# 922                                                NaN
# 923                                   3305-00327-00055
# 924                                                NaN
# 925                                   3305-00327-00056
# 926                                                NaN
# 927                                                NaN
# 928                                   3305-00327-00050
# 929                                   3305-00327-00051
# 930                                                NaN
# 931                                                NaN
# 932                                   3305-00327-00049
#
#                         Post Deployment  \
# 876                    3305-00508-00040
# 877                                 NaN
# 878                    3305-00508-00010
# 879  3305-00508-00022\n3305-00508-00041
# 880                                 NaN
# 881                    3305-00508-00024
# 882                    3305-00508-00009
# 883                    3305-00508-00023
# 884                    3305-00508-00001
# 885                    3305-00508-00038
# 886                    3305-00508-00020
# 887                    3305-00508-00011
# 888  3305-00508-00012\n3305-00508-00043
# 889                    3305-00508-00021
# 890                    3305-00508-00025
# 891                    3305-00508-00026
# 892                    3305-00508-00044
# 893  3305-00508-00014\n3305-00508-00049
# 894                    3305-00508-00015
# 895                    3305-00508-00013
# 896                    3305-00508-00045
# 916                                 NaN
# 917                    3305-00527-00036
# 918                    3305-00527-00034
# 919                    3305-00527-00035
# 920                                 NaN
# 921                                 NaN
# 922                                 NaN
# 923                                 NaN
# 924                                 NaN
# 925                                 NaN
# 926                                 NaN
# 927                                 NaN
# 928                    3305-00527-00039
# 929                    3305-00527-00038
# 930                                 NaN
# 931                                 NaN
# 932                    3305-00527-00033
#
# 883  2014-06-26 00:00:00     CP03ISSM-00001\nCP03ISSM-00004\nCP03ISSM-00006
# 884  2014-06-26 00:00:00     CP01CNSM-00002\nCP01CNSM-00003\nCP03ISSM-00005
# 885  2014-09-24 00:00:00         CP3a Spare\nCP04OSSM-00002\nGI01SUMO-00003
# 886  2014-09-24 00:00:00  GS/A Spare\nCP4 Spare\nGI01SUMO-00002\nGI01SUM...
# 887  2014-11-10 00:00:00                     GA01SUMO-00001\nGA01SUMO-00003
# 888  2014-11-10 00:00:00          GA01SUMO-00001\nCP8 Spare\nCP03ISSM-00007
# 889  2015-06-15 00:00:00                     GI01SUMO-00002\nGI01SUMO-00004
# 890  2015-06-15 00:00:00                                     GA01SUMO-00002
# 891  2015-06-15 00:00:00                     GA01SUMO-00002\nCP04OSSM-00007
# 892  2015-06-15 00:00:00                                     GS01SUMO-00002
# 893  2015-08-10 00:00:00                     CP04OSSM-00003\nGS01SUMO-00003
# 894  2015-08-10 00:00:00                     CP03ISSM-00003\nGA01SUMO-00003
# 895  2015-08-10 00:00:00                     CP01CNSM-00004\nGS01SUMO-00003
# 896  2015-08-10 00:00:00                           GI Spare\nCP01CNSM-00008
# 916  2017-09-25 00:00:00                       Pioneer 10 Spare\nGS 5 spare
# 917  2017-09-25 00:00:00                                     CP01CNSM-00009
# 918  2017-09-25 00:00:00                                     CP04OSSM-00008
# 919  2017-09-25 00:00:00                                     CP03ISSM-00008
# 920  2017-11-17 00:00:00                                     GI01SUMO-00005
# 921  2017-11-17 00:00:00                                     GI01SUMO-00005
# 922  2017-11-17 00:00:00                                                NaN
# 923  2017-11-17 00:00:00                          P11 spare\nCP04OSSM-00010
# 924  2017-11-17 00:00:00                                     CP01CNSM-00011
# 925  2017-11-17 00:00:00                                     CP03ISSM-00010
# 926  2017-11-17 00:00:00                                                NaN
# 927  2017-11-17 00:00:00                                                NaN
# 928  2017-11-27 00:00:00                                     CP03ISSM-00009
# 929  2017-12-05 00:00:00                                     CP01CNSM-00010
# 930  2017-12-05 00:00:00                                                NaN
# 931  2017-12-05 00:00:00                                                NaN
# 932  2017-12-05 00:00:00                   Irminger 5 Spare\nCP04OSSM-00009
#
#     Current Deployment Instrument Location on Current Deployment  \
# 876                NaN                                      NSIF
# 877                NaN                                      NSIF
# 878                NaN                                      NSIF
# 879                NaN                                      NSIF
# 880                NaN                                       NaN
# 881                NaN                                      NSIF
# 882                NaN                                      NSIF
# 883                NaN                                      NSIF
# 884                NaN                                      NSIF
# 885                NaN                                      NSIF
# 886                NaN                                      Buoy
# 887                NaN                                      NSIF
# 888                NaN                                       NaN
# 889                NaN                                      NSIF
# 890                NaN                                       NaN
# 891                NaN                                       NaN
# 892                NaN                                       NaN
# 893                NaN                                       NaN
# 894                NaN                            Bottom of Buoy
# 895                NaN                                       NaN
# 896                NaN                                       NaN
# 916                NaN                                       NaN
# 917                NaN                                       NaN
# 918                NaN                                       NaN
# 919                NaN                                       NaN
# 920     GI01SUMO-00005                                       NaN
# 921     GI01SUMO-00005                                       NaN
# 922     GS01SUMO-00004                            Bottom of Buoy
# 923     CP04OSSM-00010                                      NSIF
# 924     CP01CNSM-00011                                      NSIF
# 925     CP03ISSM-00010                                      NSIF
# 926     GI01SUMO-00006                                      Buoy
# 927     GI01SUMO-00006                                      NSIF
# 928                NaN                                      NSIF
# 929                NaN                                      NSIF
# 930     GS01SUMO-00004                                      NSIF
# 931                NaN                                       NaN
# 932                NaN                                       NaN
#
#                                                  Notes
# 876  Reading High nitrate levels during calibration...
# 877  09/2017: Clock issue - resets back to Jan 1, 2...
# 878  Sent to vedor as part of trade in for new (SUN...
# 879  Returned to vendor 6/24/14 (RMA#2014-125)\nSen...
# 880  Sent to vedor as part of trade in for new (SUN...
# 881  Sent to vedor as part of trade in for new (SUN...
# 882  Sent to vedor as part of trade in for new (SUN...
# 883  4/2016: Scheduled to sample every half hour. S...
# 884  Sent to vedor as part of trade in for new (SUN...
# 885  Sent to vedor as part of trade in for new (SUN...
# 886                                                NaN
# 887  Sent to vedor as part of trade in for new (SUN...
# 888  Pulled off our GI01SUMO-00003 buoy due to fail...
# 889                                                NaN
# 890  09/2017: Clock issue - resets back to Jan 1, 2...
# 891  Sent to vedor as part of trade in for new (SUN...
# 892                                                NaN
# 893                                                NaN
# 894  Sent to vedor as part of trade in for new (SUN...
# 895                                                NaN
# 896  5/2016: Removed from platform during burn in. ...
# 916                                                NaN
# 917                                                NaN
# 918                                                NaN
# 919                                                NaN
# 920                                                NaN
# 921                                                NaN
# 922  2018-04-10 Using for temporary platform testin...
# 923                                                NaN
# 924                                                NaN
# 925                                                NaN
# 926                                                NaN
# 927                                                NaN
# 928                                                NaN
# 929                                                NaN
# 930                                                NaN
# 931                                                NaN
# 932                                                NaN
#
# [38 rows x 25 columns]

# %% [markdown]
# **====================================================================================================================**
# ### Find & Parse the source file
# Now, we want to find the source file of the calibration coefficients, parse the data using the optaa parser, and read the data into a pandas dataframe. The key pieces of data needed for the parser are:
# 1. Instrument UID: This is needed to initialize the OPTAA parser
# 2. Source file: This is the full path to the source file. Zip files are acceptable input.

# %% [markdown]
# If the predeployment file is not listed in asset tracking, need to hunt through all the predeployment files for the possible candidates:

# %%
files = [file for file in os.listdir(doc_directory) if 'A' in file]
pre_files = []
for file in files:
    if '308' in file or '327' in file:
        pre_files.append(file)

# %%
pre_paths = []
predeployment = {}
for file in pre_files:
    path = generate_file_path(doc_directory, file, ext=['.zip'])
    with ZipFile(path) as zfile:
        cal_files = [file for file in zfile.namelist() if file.lower().endswith('.cal')]
        if len(cal_files) > 0:
            data = zfile.read(cal_files[0]).decode('ascii')
            lines = data.splitlines()
            _, items, *ignore = lines[0].split(',')
            inst, sn, *ignore = items.split()
            sn = sn.lstrip('0')
            if inst == 'SUNA':
                sn = 'NTR-'+sn
    if predeployment.get(sn) is None:
        predeployment.update({sn: [file]})
    else:
        predeployment[sn].append(file)

# %%
predeployment

# %%
sn = '708'
file = predeployment.get(sn)
file

# %%
pre_path = generate_file_path(doc_directory, file[0], ['.zip'])
pre_path

# %% [markdown]
# Initialize the parser:

# %%
os.listdir(cal_directory)
# Out:
# ['NUTNR-B_ISUS_SN_239_Calibration_Files _2012-11-30.zip',
#  'NUTNR-B_ISUS_SN_239_Calibration_Files_2012-10-08.zip',
#  'NUTNR-B_ISUS_SN_239_Calibration_Files_2016-02-29.zip',
#  'NUTNR-B_ISUS_SN_239_Calibration_Files_2016-09-30.zip',
#  'NUTNR-B_ISUS_SN_239_Verification_Checklist_2012-10-08.pdf',
#  'NUTNR-B_ISUS_SN_239_Verification_Checklist_2012-11-30.pdf',
#  'NUTNR-B_ISUS_SN_239_Verification_Checklist_2016-02-29.pdf',
#  'NUTNR-B_ISUS_SN_239_Verification_Checklist_2016-09-30.pdf',
#  'NUTNR-B_ISUS_SN_240_Calibration_Files _2012-11-30.zip',
#  'NUTNR-B_ISUS_SN_240_Calibration_Files_2012-10-08.zip',
#  'NUTNR-B_ISUS_SN_244_Calibration_Files_2015-07-16.zip',
#  'NUTNR-B_ISUS_SN_244_Calibration_Files_2016-07-12.zip',
#  'NUTNR-B_ISUS_SN_244_Calibration_Files_2017-08-02.zip',
#  'NUTNR-B_ISUS_SN_244_Refurb_report_2015-07-16.pdf',
#  'NUTNR-B_ISUS_SN_244_Verification_Checklist_2012-11-12.pdf',
#  'NUTNR-B_ISUS_SN_244_Verification_Sheets_2015-07-16.pdf',
#  'NUTNR-B_ISUS_SN_253_Calibration_Files_2012-12-27.zip',
#  'NUTNR-B_ISUS_SN_253_Calibration_Files_2015-12-10.zip',
#  'NUTNR-B_ISUS_SN_253_Calibration_Files_2017-01-07.zip',
#  'NUTNR-B_ISUS_SN_253_Refurb_Report_2016-01-11.pdf',
#  'NUTNR-B_ISUS_SN_253_Verification_Checklist_2012-12-27.pdf',
#  'NUTNR-B_ISUS_SN_254_Calibration_Files_2012-12-27.zip',
#  'NUTNR-B_ISUS_SN_254_Calibration_Files_2015-07-16.zip',
#  'NUTNR-B_ISUS_SN_254_Calibration_Files_2016-07-21.zip',
#  'NUTNR-B_ISUS_SN_254_Calibration_Files_2016-10-13.zip',
#  'NUTNR-B_ISUS_SN_261_calibration_Files_2013-08-30.zip',
#  'NUTNR-B_ISUS_SN_261_Calibration_Files_2014-10-29.zip',
#  'NUTNR-B_ISUS_SN_261_Calibration_Files_2016-02-29.zip',
#  'NUTNR-B_ISUS_SN_261_Calibration_Files_2016-11-10.zip',
#  'NUTNR-B_ISUS_SN_261_Verification_checklists_2013-08-30.pdf',
#  'NUTNR-B_ISUS_SN_261_Verification_Checklist_2014-10-29.pdf',
#  'NUTNR-B_ISUS_SN_261_Verification_Checklist_2016-02-29.pdf',
#  'NUTNR-B_ISUS_SN_262_calibration_Files_2013-08-30.zip',
#  'NUTNR-B_ISUS_SN_262_Calibration_Files_2016-06-10.zip',
#  'NUTNR-B_ISUS_SN_262_Calibration_Files_2016-10-06.zip',
#  'NUTNR-B_ISUS_SN_262_Service_Report_2016-06-10.pdf',
#  'NUTNR-B_ISUS_SN_262_Verification_checklists_2013-08-30.pdf',
#  'NUTNR-B_ISUS_SN_262_Verification_Report_2016-10-06.pdf',
#  'NUTNR-B_ISUS_SN_263_Calibration_Files_2013-07-25.zip',
#  'NUTNR-B_ISUS_SN_263_Calibration_Files_2015-12-11.zip',
#  'NUTNR-B_ISUS_SN_263_Calibration_Files_2017-01-07.zip',
#  'NUTNR-B_ISUS_SN_266_Calibration_files_2015-10-09.zip',
#  'NUTNR-B_ISUS_SN_266_Calibration_Files_2016-11-10.zip',
#  'NUTNR-B_ISUS_SN_266_Service_Report_2015-10-09.pdf',
#  'NUTNR-B_ISUS_SN_266_Verification_Sheet_2014-06-28.pdf',
#  'NUTNR-B_ISUS_SN_267_Calibration_Files_2014-06-28.zip',
#  'NUTNR-B_ISUS_SN_267_Calibration_Files_2016-06-27.zip',
#  'NUTNR-B_ISUS_SN_267_Verification_Sheet_2014-06-28.pdf',
#  'NUTNR-B_ISUS_SN_268_Calibration_Files_2014-06-28.zip',
#  'NUTNR-B_ISUS_SN_268_Calibration_Files_2016-02-29.zip',
#  'NUTNR-B_ISUS_SN_268_Calibration_Files_2016-11-10.zip',
#  'NUTNR-B_ISUS_SN_268_Verification_Checklist_2016-02-29.pdf',
#  'NUTNR-B_ISUS_SN_268_Verification_Sheet_2014-06-28.pdf',
#  'NUTNR-B_ISUS_SN_240_Calibration_Files_2015-06-18.zip',
#  'NUTNR-B_ISUS_SN_244_Calibration_Files_2012-11-12.zip',
#  'NUTNR-B_ISUS_SN_254_Refurb_report_2015-07-16.pdf',
#  'NUTNR-B_ISUS_SN_260_Verification_checklists_2013-08-30.pdf',
#  'NUTNR-B_ISUS_SN_263_Refurb_Report_2016-01-11.pdf',
#  'NUTNR-B_ISUS_SN_266_Calibration_Files_2014-06-28.zip',
#  'NUTNR-B_ISUS_SN_269_Calibration_Files_2014-06-28.zip',
#  'NUTNR-B_ISUS_SN_271_Verification_Checklist_2014-10-01.pdf',
#  'NUTNR-B_ISUS_SN_277_Calibration_Files_2015-06-18.zip',
#  'NUTNR-B_ISUS_SN_287_Calibration_Files_2015-09-04.zip',
#  'NUTNR-B_SUNA_SN_1057_Calibration_Files_2017-09-05.zip',
#  'NUTNR-B_SUNA_SN_1129_Calibration_Files_2017-12-20.zip',
#  'NUTNR-B_SUNA_SN_NTR-1063_Calibration_Files_2017-09-05.zip',
#  'NUTNR-B_SUNA_SN_NTR-1090_Calibration_Files_2017-10-24.zip',
#  'NUTNR_Battery_SN_230_Refurb_Report_2016-06-27.pdf',
#  'NUTNR-B_ISUS_SN_272_Calibration_Files_2014-11-19.zip',
#  'NUTNR-B_ISUS_SN_272_Calibration_Files_2016-06-01.zip',
#  'NUTNR-B_ISUS_SN_272_Verification_Checklist_2014-11-19.pdf',
#  'NUTNR-B_ISUS_SN_273_Calibration_Files_2014-11-19.zip',
#  'NUTNR-B_ISUS_SN_273_Calibration_Files_2016-06-01.zip',
#  'NUTNR-B_ISUS_SN_273_Calibration_Files_2016-11-22.zip',
#  'NUTNR-B_ISUS_SN_273_Verification_Checklist_2014-11-19.pdf',
#  'NUTNR-B_ISUS_SN_274_Calibration_Files_2015-06-18.zip',
#  'NUTNR-B_ISUS_SN_274_Calibration_Files_2016-11-09.zip',
#  'NUTNR-B_ISUS_SN_274_Verification_Checklist_2015-06-18.pdf',
#  'NUTNR-B_ISUS_SN_275_Calibration_Files_2015-06-18.zip',
#  'NUTNR-B_ISUS_SN_275_Calibration_Files_2017-06-15.zip',
#  'NUTNR-B_ISUS_SN_275_Calibration_Files_2018-06-01.zip',
#  'NUTNR-B_ISUS_SN_275_Verification_Checklist_2015-06-18.pdf',
#  'NUTNR-B_ISUS_SN_276_Calibration_Files_2015-06-18.zip',
#  'NUTNR-B_ISUS_SN_276_Calibration_Files_2017-06-06.zip',
#  'NUTNR-B_ISUS_SN_276_Verification_Checklist_2015-06-18.pdf',
#  'NUTNR-B_ISUS_SN_277_Calibration_Files_2017-06-06.zip',
#  'NUTNR-B_ISUS_SN_277_Verification_Checklist_2015-06-18.pdf',
#  'NUTNR-B_ISUS_SN_280_Calibration_Files_2015-08-10.zip',
#  'NUTNR-B_ISUS_SN_280_Calibration_Files_2016-06-27.zip',
#  'NUTNR-B_ISUS_SN_280_Verification_Checklist_2015-08-10.pdf',
#  'NUTNR-B_ISUS_SN_283_Calibration_Files_2015-08-10.zip',
#  'NUTNR-B_ISUS_SN_283_Calibration_Files_2016-06-27.zip',
#  'NUTNR-B_ISUS_SN_283_Verification_Checklist_2015-08-10.pdf',
#  'NUTNR-B_ISUS_SN_284_Calibration_Files_2015-08-10.zip',
#  'NUTNR-B_ISUS_SN_284_Calibration_Files_2016-06-27.zip',
#  'NUTNR-B_ISUS_SN_284_Verification_Checklist_2015-08-10.pdf',
#  'NUTNR-B_ISUS_SN_285_Calibration_Files_2015-08-10.zip',
#  'NUTNR-B_ISUS_SN_285_Calibration_Files_2016-09-27.zip',
#  'NUTNR-B_ISUS_SN_285_Verification_Checklist_2015-08-10.pdf',
#  'NUTNR-B_ISUS_SN_285_Verification_Checklist_2016-09-27.pdf',
#  'NUTNR-B_ISUS_SN_286 _Verification Checklist_2015-09-15.pdf',
#  'NUTNR-B_ISUS_SN_286_Calibration_Files_2015-09-04.zip',
#  'NUTNR-B_ISUS_SN_286_Calibration_Files_2016-07-13.zip',
#  'NUTNR-B_ISUS_SN_286_Calibration_Files_2017-08-02.zip',
#  'NUTNR-B_ISUS_SN_287 _Verification Checklist_2015-09-15.pdf',
#  'NUTNR-B_ISUS_SN_287_Calibration_Files_2016-07-13.zip',
#  'NUTNR-B_ISUS_SN_287_Calibration_Files_2016-10-13.zip',
#  'NUTNR-B_ISUS_SN_287_Refurb_report_2016-10-12.pdf',
#  'NUTNR-B_ISUS_SN_288 _Verification Checklist_2015-09-15.pdf',
#  'NUTNR-B_ISUS_SN_288_Calibration_Files_2015-09-15.zip',
#  'NUTNR-B_ISUS_SN_288_Calibration_Files_2016-07-12.zip',
#  'NUTNR-B_ISUS_SN_289 _Verification Checklist_2015-09-15.pdf',
#  'NUTNR-B_ISUS_SN_289_Calibration_Files_2015-09-08.zip',
#  'NUTNR-B_ISUS_SN_289_Calibration_Files_2017-01-07.zip',
#  'NUTNR-B_SUNA_SN_1056_Calibration_Files_2017-08-22.zip',
#  'NUTNR-B_ISUS_SN_254_Refurb_report_2016-10-12.pdf',
#  'NUTNR-B_ISUS_SN_254_Verification_Checklist_2012-12-27.pdf',
#  'NUTNR-B_ISUS_SN_254_Verification_Sheets_2015-07-16.pdf',
#  'NUTNR-B_ISUS_SN_255_Calibration_Files_2012-12-27.zip',
#  'NUTNR-B_ISUS_SN_255_Calibration_Files_2015-12-10.zip',
#  'NUTNR-B_ISUS_SN_255_Calibration_Files_2017-01-07.zip',
#  'NUTNR-B_ISUS_SN_255_Refurb_Report_2016-01-11.pdf',
#  'NUTNR-B_ISUS_SN_255_Verification_Checklist_2012-12-27.pdf',
#  'NUTNR-B_ISUS_SN_256_Calibration_files_2012_12_27.zip',
#  'NUTNR-B_ISUS_SN_256_Calibration_Files_2016-07-13.zip',
#  'NUTNR-B_ISUS_SN_256_Calibration_Files_2016-08-23.zip',
#  'NUTNR-B_ISUS_SN_256_Calibration_Files_2017-08-02.zip',
#  'NUTNR-B_ISUS_SN_256_Service_Report_2016-09-01.pdf',
#  'NUTNR-B_ISUS_SN_256_Verification_Checklist_2012-12-27.pdf',
#  'NUTNR-B_ISUS_SN_260_calibration_Files_2013-08-30.zip',
#  'NUTNR-B_ISUS_SN_260_Calibration_Files_2016-06-27.zip',
#  'NUTNR-B_ISUS_SN_263_Verification_Checklist_2013-07-25.pdf',
#  'NUTNR-B_ISUS_SN_264_Calibration_Files_2014-02-10.zip',
#  'NUTNR-B_ISUS_SN_264_Calibration_Files_2015-12-11.zip',
#  'NUTNR-B_ISUS_SN_264_Calibration_Files_2017-01-07.zip',
#  'NUTNR-B_ISUS_SN_264_Refurb_Report_2016-01-11.pdf',
#  'NUTNR-B_ISUS_SN_264_Verification_Sheets_2014-02-10.pdf',
#  'NUTNR-B_ISUS_SN_265_Calibration_Files_2014-02-10.zip',
#  'NUTNR-B_ISUS_SN_265_Calibration_Files_2015-12-10.zip',
#  'NUTNR-B_ISUS_SN_265_Calibration_Files_2017-08-16.zip',
#  'NUTNR-B_ISUS_SN_265_Refurb_Report_2016-01-11.pdf',
#  'NUTNR-B_ISUS_SN_265_Verification_Sheets_2014-02-10.pdf',
#  'NUTNR_Battery_SN_242_Refurb_Report_2015-07-16.pdf',
#  'NUTNR_Battery_SN_289_Refurb_Report_2015-07-16.pdf',
#  'NUTNR_Battery_SN_291_Refurb_Report_2016-06-27.pdf',
#  'NUTNR_Battery_SN_333_Service_Report_2016-12-07.pdf',
#  'NUTNR_Battery_SN_335_Service_Report_2016-11-15.pdf',
#  'NUTNR_Battery_SN_357_Service_Report_2016-06-01.pdf',
#  'NUTNR_Battery_SN_357_Service_Report_2016-12-07.pdf',
#  'NUTNR_Battery_SN_358_Service_Report_2016-06-01.pdf',
#  'NUTNR_Battery_SN_404_Service_Report_2016-11-15.pdf',
#  'NUTNR_Battery_SN_412_Refurb_Report_2016-06-27.pdf',
#  'NUTNR_Battery_SN_413_Refurb_Report_2016-06-27.pdf',
#  'NUTNR_Battery_SN_414_Refurb_Report_2016-06-27.pdf',
#  'NUTNR_Battery_SN_415_Service_Report_2016-12-07.pdf',
#  'NUTNR_Battery_SN_lost_Refurb_Report_2015-05-14.pdf',
#  '_V',
#  'NUTNR-B_ISUS_SN_269_Calibration_Files_2016-02-29.zip',
#  'NUTNR-B_ISUS_SN_269_Verification_Checklist_2016-02-29.pdf',
#  'NUTNR-B_ISUS_SN_269_Verification_Sheet_2014-06-28.pdf',
#  'NUTNR-B_ISUS_SN_270_Calibration_Files_2014-10-01.zip',
#  'NUTNR-B_ISUS_SN_270_Calibration_Files_2016-02-29.zip',
#  'NUTNR-B_ISUS_SN_270_Verification_Checklist_2014-10-01.pdf',
#  'NUTNR-B_ISUS_SN_270_Verification_Checklist_2016-02-29.pdf',
#  'NUTNR-B_ISUS_SN_271_Calibration_Files_2014-10-01.zip',
#  'NUTNR-B_ISUS_SN_271_Calibration_Files_2016-10-07.zip',
#  'NUTNR-B_SUNA_SN_1058_Calibration_Files_2017-09-05.zip',
#  'NUTNR-B_SUNA_SN_1059_1061_1129_SERVICE_Report_1005504583_2018-04-28.pdf',
#  'NUTNR-B_SUNA_SN_1059_Calibration_Files_2017-09-05.zip',
#  'NUTNR-B_SUNA_SN_1059_Calibration_Files_2018-04-26.zip',
#  'NUTNR-B_SUNA_SN_1060_Calibration_Files_2017-09-06.zip',
#  'NUTNR-B_SUNA_SN_1060_Calibration_Files_2018-12-31.zip',
#  'NUTNR-B_SUNA_SN_1061_Calibration_Files_2017-09-06.zip',
#  'NUTNR-B_SUNA_SN_1061_Calibration_Files_2018-04-26.zip',
#  'NUTNR-B_SUNA_SN_1115_Calibration_Files_2017-12-09.zip',
#  'NUTNR-B_SUNA_SN_1127_Calibration_Files_2017-12-20.zip',
#  'NUTNR-B_SUNA_SN_1128_Calibration_Files_2017-12-20.zip',
#  'NUTNR-B_SUNA_SN_NTR-1063_Calibration_Files_2018-12-20.zip',
#  'NUTNR-B_SUNA_SN_NTR-1064_Calibration_Files_2017-09-05.zip',
#  'NUTNR-B_SUNA_SN_NTR-1064_Calibration_Files_2018-12-19.zip',
#  'NUTNR-B_SUNA_SN_NTR-1065_Calibration_Files_2017-09-06.zip',
#  'NUTNR-B_SUNA_SN_NTR-1065_Calibration_Files_2018-12-20.zip',
#  'NUTNR-B_SUNA_SN_NTR-1086_Calibration_Files_2017-09-28.zip',
#  'NUTNR-B_SUNA_SN_NTR-1087_Calibration_Files_2017-10-25.zip',
#  'NUTNR-B_SUNA_SN_NTR-1088_Calibration_Files_2017-10-26.zip',
#  'NUTNR-B_SUNA_SN_NTR-1089_Calibration_Files_2017-10-26.zip',
#  'NUTNR-B_SUNA_SN_1129_Calibration_Files_2018-04-26.zip',
#  'NUTNR-B_SUNA_SN_1164_Calibration_Files_2018-06-11.zip',
#  'NUTNR-B_SUNA_SN_1167_Calibration_Files_2018-06-11.zip',
#  'NUTNR-B_SUNA_SN_1183_Calibration_Files_2018-06-11.zip',
#  'NUTNR-B_SUNA_SN_344_Calibration_Files_2013-07-25.zip',
#  'NUTNR-B_SUNA_SN_344_Verification_Checklist_2013-07-25.pdf',
#  'NUTNR-B_SUNA_SN_400_Calibration_Files_2017-09-19.zip',
#  'NUTNR-B_SUNA_SN_625_Calibration_Files_2015-05-22.zip',
#  'NUTNR-B_SUNA_SN_625_Verification_Checklist_2015-05-26.pdf',
#  'NUTNR-B_SUNA_SN_NTR-1057_Calibration_Files_2018-12-31.zip',
#  'NUTNR-B_SUNA_SN_NTR-1058_Calibration_Files_2018-12-31.zip',
#  'NUTNR-B_SUNA_SN_NTR-1060_Calibration_Files_2018-12-31.zip',
#  'NUTNR-B_SUNA_SN_NTR-1062_Calibration_Files_2017-09-02.zip',
#  'NUTNR-B_ISUS_SN_240_Calibration_Files_2017-06-15.zip',
#  'NUTNR-B_ISUS_SN_240_Calibration_Files_2018-05-31.zip',
#  'NUTNR-B_ISUS_SN_240_Verification_Checklist_2012-10-08.pdf',
#  'NUTNR-B_ISUS_SN_240_Verification_Checklist_2012-11-30.pdf',
#  'NUTNR-B_ISUS_SN_240_Verification_Checklist_RMA_Report_2015-06-18.pdf',
#  'NUTNR-B_ISUS_SN_243_Calibration_Files_2012-11-12.zip',
#  'NUTNR-B_ISUS_SN_243_Calibration_Files_2015-04-27.zip',
#  'NUTNR-B_ISUS_SN_243_Calibration_Files_2017-01-07.zip',
#  'NUTNR-B_ISUS_SN_243_Verification_Checklist_2012-11-12.pdf',
#  'NUTNR-B_ISUS_SN_243_Verification_Sheets_2014-05-14.pdf',
#  'NUTNR-B_SUNA_SN_NTR-1091_Calibration_Files_2017-10-24.zip',
#  'NUTNR-B_SUNA_SN_NTR-1092_Calibration_Files_2017-10-16.zip',
#  'NUTNR-B_SUNA_SN_NTR-1093_Calibration_Files_2017-10-27.zip',
#  'NUTNR-B_SUNA_SN_NTR-1094_Calibration_Files_2017-11-09.zip',
#  'NUTNR-B_SUNA_SN_NTR-1102_Calibration_Files_2017-11-27.zip',
#  'NUTNR-B_SUNA_SN_NTR-1103_Calibration_Files_2017-11-27.zip',
#  'NUTNR-B_SUNA_SN_NTR-1106_Calibration_Files_2017-11-28.zip',
#  'NUTNR-B_SUNA_SN_NTR-1107_Calibration_Files_2017-11-28.zip',
#  'NUTNR-B_SUNA_SN_NTR-1107_Calibration_Files_2019-03-13.zip',
#  'NUTNR-B_SUNA_SN_NTR-1115_Calibration_Files_2018-12-31.zip',
#  'NUTNR-B_SUNA_SN_NTR-1127_Calibration_Files_2018-12-31.zip',
#  'NUTNR-B_SUNA_SN_NTR-1128_Calibration_Files_2018-12-31.zip',
#  'NUTNR-J_SUNA_SN_0870_Calibration_Files_2018-07-25.zip',
#  'NUTNR_Battery_SN_229_Service_Report_2016-12-07.pdf']

# %%
for file in os.listdir(doc_directory):
    if '00327-00073' in file:
        print(file)
# Out:
# 3305-00327-00073-A.zip

# %%
sn = '760'
filepath = doc_directory + '/' + '3305-00327-00075-A.zip'

# %%
nutnr = NUTNRCalibration('CGINS-NUTNRM-'+sn.zfill(5))

# %% [markdown]
# Read in the calibration coefficients:

# %%
nutnr.load_cal(filepath)

# %%
nutnr.coefficients
# Out:
# {'CC_cal_temp': '20.06',
#  'CC_di': [12.125,
#   17.54166667,
#   27.16666667,
#   35.125,
#   35.29166667,
#   38.5,
#   40.41666667,
#   37.875,
#   41.5,
#   52.125,
#   105.16666667,
#   328.625,
#   1023.45833333,
#   2693.45833333,
#   5709.95833333,
#   9817.16666667,
#   13997.95833333,
#   17334.04166667,
#   19562.08333333,
#   20945.5,
#   21823.45833333,
#   22521.33333333,
#   23250.375,
#   24109.45833333,
#   25204.125,
#   26572.58333333,
#   28244.20833333,
#   30246.58333333,
#   32522.75,
#   35032.5,
#   37705.25,
#   40332.70833333,
#   42710.75,
#   44686.79166667,
#   46031.875,
#   46537.58333333,
#   46357.04166667,
#   45388.91666667,
#   43829.66666667,
#   41946.75,
#   39946.66666667,
#   38029.33333333,
#   36314.79166667,
#   34877.66666667,
#   33760.0,
#   33048.75,
#   32646.83333333,
#   32628.41666667,
#   32923.04166667,
#   33563.875,
#   34524.20833333,
#   35811.0,
#   37325.83333333,
#   39104.0,
#   41120.33333333,
#   43251.29166667,
#   45488.0,
#   47666.08333333,
#   49763.875,
#   51639.66666667,
#   53151.79166667,
#   54160.04166667,
#   54653.66666667,
#   54566.58333333,
#   53865.75,
#   52596.33333333,
#   50911.0,
#   48833.0,
#   46629.08333333,
#   44284.54166667,
#   41980.33333333,
#   39836.91666667,
#   37817.08333333,
#   36037.58333333,
#   34475.08333333,
#   33095.95833333,
#   31909.33333333,
#   30918.20833333,
#   30104.79166667,
#   29464.16666667,
#   29000.5,
#   28667.33333333,
#   28490.33333333,
#   28473.66666667,
#   28570.83333333,
#   28827.79166667,
#   29198.375,
#   29672.20833333,
#   30264.79166667,
#   30939.45833333,
#   31662.16666667,
#   32416.04166667,
#   33189.95833333,
#   33907.625,
#   34582.75,
#   35104.91666667,
#   35466.04166667,
#   35610.20833333,
#   35529.83333333,
#   35194.70833333,
#   34634.5,
#   33824.375,
#   32828.41666667,
#   31714.58333333,
#   30471.375,
#   29174.04166667,
#   27906.79166667,
#   26709.20833333,
#   25567.58333333,
#   24513.83333333,
#   23568.04166667,
#   22720.29166667,
#   22008.33333333,
#   21386.33333333,
#   20861.83333333,
#   20442.125,
#   20108.125,
#   19859.70833333,
#   19711.75,
#   19634.45833333,
#   19642.125,
#   19735.125,
#   19906.91666667,
#   20175.45833333,
#   20513.79166667,
#   20916.54166667,
#   21422.79166667,
#   21978.04166667,
#   22601.33333333,
#   23295.95833333,
#   24044.91666667,
#   24803.95833333,
#   25628.5,
#   26472.375,
#   27313.58333333,
#   28132.91666667,
#   28953.5,
#   29696.45833333,
#   30445.75,
#   31086.375,
#   31629.08333333,
#   32104.79166667,
#   32435.58333333,
#   32675.375,
#   32756.45833333,
#   32692.41666667,
#   32515.95833333,
#   32258.75,
#   31857.95833333,
#   31373.79166667,
#   222.91,
#   223.71,
#   224.51,
#   225.32,
#   226.12,
#   226.92,
#   227.73,
#   228.53,
#   229.33,
#   230.14,
#   230.94,
#   231.75,
#   232.55,
#   233.35,
#   234.16,
#   234.96,
#   235.77,
#   236.57,
#   237.38,
#   238.18,
#   238.99,
#   239.79,
#   240.6,
#   241.4,
#   242.21,
#   243.02,
#   243.82,
#   244.63,
#   245.43,
#   246.24,
#   247.05,
#   247.85,
#   248.66,
#   249.47,
#   250.27,
#   251.08,
#   251.89,
#   252.69,
#   253.5,
#   254.31,
#   255.12,
#   255.92,
#   256.73,
#   257.54,
#   258.35,
#   259.15,
#   259.96,
#   260.77,
#   261.58,
#   262.39,
#   263.19,
#   264.0,
#   264.81,
#   265.62,
#   266.43,
#   267.24,
#   268.04,
#   268.85,
#   269.66,
#   270.47,
#   271.28,
#   272.09,
#   272.9,
#   273.71,
#   274.52,
#   275.32,
#   276.13,
#   276.94,
#   277.75,
#   278.56,
#   279.37,
#   280.18,
#   280.99,
#   281.8,
#   282.61,
#   283.42,
#   284.23,
#   285.04,
#   285.85,
#   286.65,
#   287.46,
#   288.27,
#   289.08,
#   289.89,
#   290.7,
#   291.51,
#   292.32,
#   293.13,
#   293.94,
#   294.75,
#   295.56,
#   296.37,
#   297.18,
#   297.99,
#   298.8,
#   299.61,
#   300.42,
#   301.23,
#   302.04,
#   302.84,
#   303.65,
#   304.46,
#   305.27,
#   306.08,
#   306.89,
#   307.7,
#   308.51,
#   309.32,
#   310.13,
#   310.94,
#   311.75,
#   312.56,
#   313.37,
#   314.17,
#   314.98,
#   315.79,
#   316.6,
#   317.41,
#   318.22,
#   319.03,
#   319.84,
#   320.64,
#   321.45,
#   322.26,
#   323.07,
#   323.88,
#   324.69,
#   325.49,
#   326.3,
#   327.11,
#   327.92,
#   328.73,
#   329.53,
#   330.34,
#   331.15,
#   331.96,
#   332.76,
#   333.57,
#   334.38,
#   335.19,
#   335.99,
#   336.8,
#   337.61,
#   338.41,
#   339.22,
#   340.03,
#   340.83,
#   341.64,
#   342.45,
#   343.25,
#   344.06,
#   344.86,
#   345.67,
#   346.48,
#   347.28,
#   348.09,
#   348.89,
#   349.7,
#   350.5,
#   351.31,
#   352.11,
#   352.92,
#   353.72,
#   354.53,
#   355.33,
#   356.13,
#   356.94,
#   357.74,
#   358.55,
#   359.35,
#   360.15,
#   360.96,
#   361.76,
#   362.56,
#   363.36,
#   364.17,
#   364.97,
#   365.77,
#   366.57,
#   367.38,
#   368.18,
#   368.98,
#   369.78,
#   370.58,
#   371.38,
#   372.18,
#   372.98,
#   373.79,
#   374.59,
#   375.39,
#   376.19,
#   376.99,
#   377.79,
#   378.58,
#   379.38,
#   380.18,
#   380.98,
#   381.78,
#   382.58,
#   383.38,
#   384.18,
#   384.97,
#   385.77,
#   386.57,
#   387.37,
#   388.16,
#   388.96,
#   389.76,
#   390.55,
#   391.35,
#   392.14,
#   392.94,
#   393.73,
#   394.53]}

# %% [markdown]
# Write the csv to a temporary local folder:

# %%
temp_directory = '/'.join((os.getcwd(),'temp'))
# Check if the temp directory exists; if it already does, purge and rewrite
if os.path.exists(temp_directory):
    shutil.rmtree(temp_directory)
    ensure_dir(temp_directory)
else:
    ensure_dir(temp_directory)

# %%
nutnr.write_csv(temp_directory)
# Out:
# Write CGINS-NUTNRM-00760__20190802.csv to /home/andrew/Documents/OOI-CGSN/QAQC_Sandbox/Metadata_Review/temp? [y/n]: y

# %%
(nutnr.uid, nutnr.serial, nutnr.date)
# Out:
# ('CGINS-NUTNRM-00760', 'NTR-0760', ['20190802', '20151126'])

# %%
nutnr.source
# Out:
# 'Source file: 3305-00327-00075-A.zip > 3305-00327-00075-A/SNA0760B.CAL'

# %% [markdown]
# **====================================================================================================================**
# ### Check the data
# Now, we have generated local csv and ext files from the data. We can now reload that data into python as a pandas dataframe, which will allow for a direct comparison with the existing data.

# %%
def reformat_arrays(array):
    # First, need to strip extraneous characters from the array
    array = array.replace("'","").replace('[','').replace(']','')
    # Next, split the array into a list
    array = array.split(',')
    # Now, need to eliminate any white space surrounding the individual coeffs
    array = [num.strip() for num in array]
    # Next, float the nums
    array = [float(num) for num in array]
    # Check if the array is len == 1; if so, can just return the number
    if len(array) == 1:
        array = array[0]
    # Now we are done
    return array

# %%
#sn = nutnr.serial.zfill(5)
dt = max(nutnr.date)

# %%
source_csv = pd.read_csv(temp_directory+'/CGINS-NUTNRM-00760'+'__'+dt+'.csv')
source_csv['value'] = source_csv['value'].apply(lambda x: reformat_arrays(x))
#source_csv['serial'] = 1029
source_csv
# Out:
#      serial                                       name  \
# 0  NTR-0760                                CC_cal_temp
# 1  NTR-0760                                      CC_di
# 2  NTR-0760                                    CC_eno3
# 3  NTR-0760                                    CC_eswa
# 4  NTR-0760  CC_lower_wavelength_limit_for_spectra_fit
# 5  NTR-0760  CC_upper_wavelength_limit_for_spectra_fit
# 6  NTR-0760                                      CC_wl
#
#                                                value  \
# 0                                              20.06
# 1  [12.125, 17.54166667, 27.16666667, 35.125, 35....
# 2  [0.00090013, 0.00346387, -0.00188127, -0.00140...
# 3  [0.00907539, 0.00594526, 0.01134671, 0.0056445...
# 4                                                217
# 5                                                240
# 6  [189.38, 190.17, 190.96, 191.76, 192.55, 193.3...
#
#                                                notes
# 0   Source file: 3305-00327-00075-A.zip > 3305-00...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                217
# 5                                                240
# 6                                                NaN

# %%
path = '/home/andrew/Documents/OOI-CGSN/asset-management/calibration/NUTNRM/CGINS-NUTNRM-00760__20190802.csv'
path
# Out:
# '/home/andrew/Documents/OOI-CGSN/asset-management/calibration/NUTNRM/CGINS-NUTNRM-00760__20190802.csv'

# %%
am_csv = pd.read_csv(path)
am_csv['value'] = am_csv['value'].apply(lambda x: reformat_arrays(x))
am_csv
# Out:
#    serial                                       name  \
# 0     760                                CC_cal_temp
# 1     760                                      CC_di
# 2     760                                    CC_eno3
# 3     760                                    CC_eswa
# 4     760  CC_lower_wavelength_limit_for_spectra_fit
# 5     760  CC_upper_wavelength_limit_for_spectra_fit
# 6     760                                      CC_wl
#
#                                                value  \
# 0                                              20.06
# 1  [12.125, 17.54166667, 27.16666667, 35.125, 35....
# 2  [0.00090013, 0.00346387, -0.00188127, -0.00140...
# 3  [0.00907539, 0.00594526, 0.01134671, 0.0056445...
# 4                                                217
# 5                                                240
# 6  [189.38, 190.17, 190.96, 191.76, 192.55, 193.3...
#
#                                                notes
# 0  source_file 3305-00327-00075-A_SN_760_Pre-Depl...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           Constant
# 5                                           Constant
# 6                                                NaN

# %%
am_csv['notes'].iloc[0]

# %%
source_csv['notes'].iloc[0]

# %%
source_csv == am_csv
# Out:
#    serial  name  value  notes
# 0   False  True   True  False
# 1   False  True   True  False
# 2   False  True   True  False
# 3   False  True   True  False
# 4   False  True   True  False
# 5   False  True   True  False
# 6   False  True   True  False

# %%
result = {}
for k,val in enumerate(am_csv['value'].iloc[1]):
    check = source_csv['value'].iloc[1][k] == val
    if not check:
        result.update({k:val})
result

# %%
result = {}
for k,val in enumerate(am_csv['value'].iloc[3]):
    check = source_csv['value'].iloc[3][k] == val
    if not check:
        result.update({k:val})
result

# %%
source_csv['value'].iloc[0] - am_csv['value'].iloc[0]

# %%
stuff

# %%
import re
import pandas as pd
import numpy as np
from zipfile import ZipFile

class NUTNRCalibration():
    # Class that stores calibration values for CTDs.

    def __init__(self, uid):
        self.serial = None
        self.uid = uid
        self.coefficients = {
            'CC_cal_temp':[],
            'CC_di':[],
            'CC_eno3':[],
            'CC_eswa':[],
            'CC_lower_wavelength_limit_for_spectra_fit':'217',
            'CC_upper_wavelength_limit_for_spectra_fit':'240',
            'CC_wl':[]
        }
        self.date = []
        self.notes = {
            'CC_cal_temp':'',
            'CC_di':'',
            'CC_eno3':'',
            'CC_eswa':'',
            'CC_lower_wavelength_limit_for_spectra_fit':'217',
            'CC_upper_wavelength_limit_for_spectra_fit':'240',
            'CC_wl':''
        }

    @property
    def uid(self):
        return self._uid

    @uid.setter
    def uid(self, d):
        r = re.compile('.{5}-.{6}-.{5}')
        if r.match(d) is not None:
            self._uid = d
        else:
            raise Exception(f"The instrument uid {d} is not a valid uid. Please check.")
            
    def load_cal(self, filepath):
        """
        Wrapper function to load all of the calibration coefficients
        
        Args:
            filepath - path to the directory with filename which has the
                calibration coefficients to be parsed and loaded
        Calls:
            open_cal
            parse_cal
        """
        
        data = self.open_cal(filepath)
        
        self.parse_cal(data)
    
    
    def open_cal(self, filepath):
        """
        Function that opens and reads in cal file
        information for a NUTNR. Zipfiles are acceptable inputs.
        """
        
        if filepath.endswith('.zip'):
            with ZipFile(filepath) as zfile:
                # Check if ISUS or SUNA to get the appropriate name
                filename = [name for name in zfile.namelist()
                            if name.lower().endswith('.cal') and 'z' not in name.lower()]
                
                # Get and open the latest calibration file
                if len(filename) == 1:
                    data = zfile.read(filename[0]).decode('ascii')
                    self.source_file(filepath, filename[0])
                    
                elif len(filename) > 1:
                    filename = [max(filename)]
                    data = zfile.read(filename[0]).decode('ascii')
                    self.source_file(filepath, filename[0])

                else:
                    FileExistsError(f"No .cal file found in {filepath}")
                        
        elif filepath.lower().endswith('.cal'):
            if 'z' not in filepath.lower().split('/')[-1]:
                with open(filepath) as file:
                    data = file.read()
                self.source_file(filepath, file)
        else:
            pass
        
        return data
            
        
    def source_file(self, filepath, filename):
        """
        Routine which parses out the source file and filename
        where the calibration coefficients are sourced from.
        """
        
        if filepath.lower().endswith('.cal'):
            dcn = filepath.split('/')[-2]
            filename = filepath.split('/')[-1]
        else:
            dcn = filepath.split('/')[-1]
        
        self.source = f'Source file: {dcn} > {filename}'
        
    
    def parse_cal(self, data):
        
        for k,line in enumerate(data.splitlines()):
            
            if line.startswith('H'):
                _, info, *ignore = line.split(',')
                
                # The first line of the cal file contains the serial number
                if k == 0:
                    _, sn, *ignore = info.split()
                    if 'SUNA' in info:
                        self.serial = 'NTR-' + sn
                    else:
                        self.serial = sn
                    
                
                # File creation time is when the instrument was calibrated.
                # May be multiple times for different cal coeffs
                if 'file creation time' in info.lower():
                    _, _, _, date, time = info.split()
                    date_time = pd.to_datetime(date + ' ' + time).strftime('%Y%m%d')
                    self.date.append(date_time)
                    
                # The temperature at which it was calibrated
                if 't_cal_swa' in info.lower() or 't_cal' in info.lower():
                    _, cal_temp = info.split()
                    self.coefficients['CC_cal_temp'] = cal_temp
                    
            # Now parse the calibration coefficients
            if line.startswith('E'):
                _, wl, eno3, eswa, _, di = line.split(',')
                
                self.coefficients['CC_wl'].append(float(wl))
                self.coefficients['CC_di'].append(float(di))
                self.coefficients['CC_eno3'].append(float(eno3))
                self.coefficients['CC_eswa'].append(float(eswa))
                
                
    def write_csv(self, outpath):
        """
        This function writes the correctly named csv file for the ctd to the
        specified directory.

        Args:
            outpath - directory path of where to write the csv file
        Raises:
            ValueError - raised if the CTD object's coefficient dictionary
                has not been populated
        Returns:
            self.to_csv - a csv of the calibration coefficients which is
                written to the specified directory from the outpath.
        """

        # Run a check that the coefficients have actually been loaded
        if len(self.coefficients.values()) <= 2:
            raise ValueError('No calibration coefficients have been loaded.')

        # Create a dataframe to write to the csv
        data = {
            'serial': [self.serial]*len(self.coefficients),
            'name': list(self.coefficients.keys()),
            'value': list(self.coefficients.values())
        }
        df = pd.DataFrame().from_dict(data)

        # Define a function to reformat the notes into an uniform system
        def reformat_notes(x):
            # First, get rid of 
            try:
                np.isnan(x)
                x = ''
            except:
                x = str(x).replace('[','').replace(']','')
            return x
        
        # Now merge the coefficients dataframe with the notes
        if len(self.notes) > 0:
            notes = pd.DataFrame().from_dict({
                'name':list(self.notes.keys()),
                'notes':list(self.notes.values())
            })
            df = df.merge(notes, how='outer', left_on='name', right_on='name')
        else:
            df['notes'] = ''
            
        # Add in the source file
        df['notes'].iloc[0] = df['notes'].iloc[0] + ' ' + self.source
        
        # Sort the data by the coefficient name
        df = df.sort_values(by='name')

        # Generate the csv name
        cal_date = max(self.date)
        csv_name = self.uid + '__' + cal_date + '.csv'

        # Write the dataframe to a csv file
        check = input(f"Write {csv_name} to {outpath}? [y/n]: ")
        # check = 'y'
        if check.lower().strip() == 'y':
            df.to_csv(outpath+'/'+csv_name, index=False)
