# %% [markdown]
# # OPTAA METADATA REVIEW
#
# The notebook describes the process for checking the calibration csvs located in the OOI-CGSN asset management repository on GitHub. The purpose is to identify when errors were made during entering the calibration csvs. This includes checking the following information:
#
# 1. The calibration date - this information is stored in the filename of the csv
# 2. Calibration source - identifying all the possible sources of calibration information, and determine which file should supply the calibration info
# 3. Calibration coeffs - checking the accuracy and precision of the numbers stored in the calibration coefficients
#
# ========================================================================================================================
#
# The first step is to load relevant packages:

# %%
import csv
import re
import os
import shutil
import numpy as np
import pandas as pd

# %%
from utils import *

# %% [markdown]
# **=========================================================================================================================**
# Define some useful functions for the metadata review (in future will move to a utilities file):

# %%
def get_qct_files(df, qct_directory):
    qct_dict = {}
    uids = list(set(df['UID']))
    for uid in uids:
        df['UID_match'] = df['UID'].apply(lambda x: True if uid in x else False)
        qct_series = df[df['UID_match'] == True]['QCT Testing']
        qct_series = list(qct_series.iloc[0].split('\n'))
        qct_dict.update({uid:qct_series})
    return qct_dict

# %%
def get_calibration_files(serial_nums, cal_directory):
    calibration_files = {}
    for uid in serial_nums.keys():
        sn = serial_nums.get(uid)
        sn = str(sn[0])
        files = []
        for file in os.listdir(cal_directory):
            if 'Calibration_File' in file:
                if sn in file:
                    files.append(file)
        calibration_files.update({uid:files})
    return calibration_files

# %%
# Now I need to load the all of the csv files based on their UID
def load_csv_info(csv_dict,filepath):
    """
    Loads the calibration coefficient information contained in asset management
    
    Args:
        csv_dict - a dictionary which associates an instrument UID to the
            calibration csv files in asset management
        filepath - the path to the directory containing the calibration csv files
    Returns:
        csv_cals - a dictionary which associates an instrument UID to a pandas
            dataframe which contains the calibration coefficients. The dataframes
            are indexed by the date of calibration
    """
    
    # Load the calibration data into pandas dataframes, which are then placed into
    # a dictionary by the UID
    csv_cals = {}
    for uid in csv_dict:
        cals = pd.DataFrame()
        for file in csv_dict[uid]:
            data = pd.read_csv(filepath+file)
            date = file.split('__')[1].split('.')[0]
            data['CAL DATE'] = pd.to_datetime(date)
            cals = cals.append(data)
        csv_cals.update({uid:cals})
        
    # Pivot the dataframe to be sorted based on calibration date
    for uid in csv_cals:
        csv_cals[uid] = csv_cals[uid].pivot(index=csv_cals[uid]['CAL DATE'], columns='name')['value']
        
    return csv_cals

# %%
def splitDataFrameList(df,target_column):
    ''' 
    df = dataframe to split,
    target_column = the column containing the values to split
    separator = the symbol used to perform the split
    returns: a dataframe with each entry for the target column separated, with each element moved into a new row. 
    The values in the other columns are duplicated across the newly divided rows.
    '''
    
    def splitListToRows(row,row_accumulator,target_column):
        split_row = row[target_column]
        for s in split_row:
            new_row = row.to_dict()
            new_row[target_column] = s
            row_accumulator.append(new_row)
            
    new_rows = []
    df.apply(splitListToRows,axis=1,args = (new_rows,target_column))
    new_df = pd.DataFrame(new_rows)
    return new_df

# %%
# Now, write a function to copy over the file
def copy_to_local(cal_path):
    """
    Function which copies the files from the cal_path to a locally
    created temp directory
    """
    
    for filepath in cal_path:
        # Create a folder in which to save extracted data
        folder, *ignore = filepath.split('/')[-1].split('.')
        savedir = '/'.join((os.getcwd(),'temp','cal_data',folder))
        # Now make sure that the save directory exists and can be used
        ensure_dir(savedir)
    
        if filepath.endswith('.zip'):
            with ZipFile(filepath,'r') as zfile:
                for file in zfile.namelist():
                    zfile.extract(file,path=savedir)    
        else:
            shutil.copy(filepath, savedir)

# %% [markdown]
# **=======================================================================================================================**
# Define the directories where the QCT, Pre, and Post deployment document files are stored, where the vendor documents are stored, where asset tracking is located, and where the calibration csvs are located.

# %%
doc_directory = '/media/andrew/OS/Users/areed/Documents/Project_Files/Records/Instrument_Records/OPTAA/OPTAA_Results/'
cal_directory = '/media/andrew/OS/Users/areed/Documents/Project_Files/Records/Instrument_Records/OPTAA/OPTAA_Cal/'
asset_management_directory = '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/'

# %%
excel_spreadsheet = '/media/andrew/OS/Users/areed/Documents/Project_Files/Documentation/System/System Notebook/WHOI_Asset_Tracking.xlsx'
sheet_name = 'Sensors'

# %%
OPTAA = whoi_asset_tracking(spreadsheet=excel_spreadsheet,sheet_name=sheet_name,instrument_class='OPTAA')

# %%
OPTAA[['UID','QCT Testing']]
# Out:
#                     UID                                        QCT Testing
# 933  CGINS-OPTAAD-00123  3305-00113-00002\n3305-00113-00011\n3305-00113...
# 934  CGINS-OPTAAD-00129  3305-00113-00005\n3305-00113-00067\n3305-00113...
# 935  CGINS-OPTAAD-00130  3305-00113-00006\n3305-00113-00044\n3305-00113...
# 936  CGINS-OPTAAD-00150                 3305-00113-00014\n3305-00113-00088
# 937  CGINS-OPTAAD-00151  3305-00113-00015\n3305-00113-00083\n3305-00113...
# 938  CGINS-OPTAAD-00152  3305-00113-00016\n3305-00113-00036\n3305-00113...
# 939  CGINS-OPTAAD-00153  3305-00113-00017\n3305-00113-00094      3305-0...
# 940  CGINS-OPTAAD-00159  3305-00113-00018\n3305-00113-00086\n3305-00113...
# 941  CGINS-OPTAAD-00165  3305-00113-00020\n3305-00113-00072\n3305-00113...
# 942  CGINS-OPTAAD-00185  3305-00112-00030\n3305-00113-00085\n3305-00113...
# 943  CGINS-OPTAAD-00187  3305-00113-00032\n3305-00113-00091\n3305-00113...
# 944  CGINS-OPTAAD-00189  3305-00113-00033\n3305-00113-00071\n3305-00113...
# 945  CGINS-OPTAAD-00193  3305-00113-00034\n3305-00113-00089\n3305-00113...
# 946  CGINS-OPTAAD-00205                 3305-00113-00035\n3305-00113-00136
# 947  CGINS-OPTAAD-00206  3305-00113-00037\n3305-00113-00137\n3305-00113...
# 948  CGINS-OPTAAD-00207                3305-00113-00038   3305-00113-00131
# 949  CGINS-OPTAAD-00209  3305-00113-00039\n3305-00113-00099\n3305-00113...
# 950  CGINS-OPTAAD-00218  3305-00113-00045\n3305-00113-00055\n3305-00113...
# 951  CGINS-OPTAAD-00222  3305-00113-00050\n3305-00113-00111\n3305-00113...
# 952  CGINS-OPTAAD-00240  3305-00113-00048\n3305-00113-00087\n3305-00113...
# 953  CGINS-OPTAAD-00241  3305-00113-00047\n3305-00113-00084\n3305-00113...
# 954  CGINS-OPTAAD-00242  3305-00113-00049\n3305-00113-00110\n3305-00113...
# 955  CGINS-OPTAAD-00245                 3305-00113-00052\n3305-00113-00134
# 956  CGINS-OPTAAD-00254                 3305-00113-00056\n3305-00113-00146
# 957  CGINS-OPTAAD-00255  3305-00113-00057\n3305-00113-00125\n3305-00113...
# 958  CGINS-OPTAAD-00256  3305-00113-00059\n3305-00113-00102\n3305-00113...
# 959  CGINS-OPTAAD-00257  3305-00113-00061\n3305-00113-00098    3305-001...

# %% [markdown]
# **=======================================================================================================================**
# Now, I want to load all the calibration csvs and group them by UID:

# %%
uids = sorted( list( set(OPTAA['UID']) ) )

# %%
csv_dict = {}
asset_management = os.listdir(asset_management_directory)
for uid in uids:
    files = [file for file in asset_management if uid in file]
    csv_dict.update({uid: sorted(files)})

# %%
csv_dict
# Out:
# {'CGINS-OPTAAD-00123': ['CGINS-OPTAAD-00123__20131121.csv',
#   'CGINS-OPTAAD-00123__20131121__CC_taarray.ext',
#   'CGINS-OPTAAD-00123__20131121__CC_tcarray.ext',
#   'CGINS-OPTAAD-00123__20151021.csv',
#   'CGINS-OPTAAD-00123__20151021__CC_taarray.ext',
#   'CGINS-OPTAAD-00123__20151021__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00129': ['CGINS-OPTAAD-00129__20131121.csv',
#   'CGINS-OPTAAD-00129__20131121__CC_taarray.ext',
#   'CGINS-OPTAAD-00129__20131121__CC_tcarray.ext',
#   'CGINS-OPTAAD-00129__20160513.csv',
#   'CGINS-OPTAAD-00129__20160513__CC_taarray.ext',
#   'CGINS-OPTAAD-00129__20160513__CC_tcarray.ext',
#   'CGINS-OPTAAD-00129__20170209.csv',
#   'CGINS-OPTAAD-00129__20170209__CC_taarray.ext',
#   'CGINS-OPTAAD-00129__20170209__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00130': ['CGINS-OPTAAD-00130__20150509.csv',
#   'CGINS-OPTAAD-00130__20150509__CC_taarray.ext',
#   'CGINS-OPTAAD-00130__20150509__CC_tcarray.ext',
#   'CGINS-OPTAAD-00130__20161125.csv',
#   'CGINS-OPTAAD-00130__20161125__CC_taarray.ext',
#   'CGINS-OPTAAD-00130__20161125__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00150': ['CGINS-OPTAAD-00150__20140910.csv',
#   'CGINS-OPTAAD-00150__20140910__CC_taarray.ext',
#   'CGINS-OPTAAD-00150__20140910__CC_tcarray.ext',
#   'CGINS-OPTAAD-00150__20161125.csv',
#   'CGINS-OPTAAD-00150__20161125__CC_taarray.ext',
#   'CGINS-OPTAAD-00150__20161125__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00151': ['CGINS-OPTAAD-00151__20141213.csv',
#   'CGINS-OPTAAD-00151__20141213__CC_taarray.ext',
#   'CGINS-OPTAAD-00151__20141213__CC_tcarray.ext',
#   'CGINS-OPTAAD-00151__20150507.csv',
#   'CGINS-OPTAAD-00151__20150507__CC_taarray.ext',
#   'CGINS-OPTAAD-00151__20150507__CC_tcarray.ext',
#   'CGINS-OPTAAD-00151__20160528.csv',
#   'CGINS-OPTAAD-00151__20160528__CC_taarray.ext',
#   'CGINS-OPTAAD-00151__20160528__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00152': ['CGINS-OPTAAD-00152__20151023.csv',
#   'CGINS-OPTAAD-00152__20151023__CC_taarray.ext',
#   'CGINS-OPTAAD-00152__20151023__CC_tcarray.ext',
#   'CGINS-OPTAAD-00152__20180711.csv',
#   'CGINS-OPTAAD-00152__20180711__CC_taarray.ext',
#   'CGINS-OPTAAD-00152__20180711__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00153': ['CGINS-OPTAAD-00153__20140910.csv',
#   'CGINS-OPTAAD-00153__20140910__CC_taarray.ext',
#   'CGINS-OPTAAD-00153__20140910__CC_tcarray.ext',
#   'CGINS-OPTAAD-00153__20161012.csv',
#   'CGINS-OPTAAD-00153__20161012__CC_taarray.ext',
#   'CGINS-OPTAAD-00153__20161012__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00159': ['CGINS-OPTAAD-00159__20141214.csv',
#   'CGINS-OPTAAD-00159__20141214__CC_taarray.ext',
#   'CGINS-OPTAAD-00159__20141214__CC_tcarray.ext',
#   'CGINS-OPTAAD-00159__20160710.csv',
#   'CGINS-OPTAAD-00159__20160710__CC_taarray.ext',
#   'CGINS-OPTAAD-00159__20160710__CC_tcarray.ext',
#   'CGINS-OPTAAD-00159__20180426.csv',
#   'CGINS-OPTAAD-00159__20180426__CC_taarray.ext',
#   'CGINS-OPTAAD-00159__20180426__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00165': ['CGINS-OPTAAD-00165__20141212.csv',
#   'CGINS-OPTAAD-00165__20141212__CC_taarray.ext',
#   'CGINS-OPTAAD-00165__20141212__CC_tcarray.ext',
#   'CGINS-OPTAAD-00165__20160527.csv',
#   'CGINS-OPTAAD-00165__20160527__CC_taarray.ext',
#   'CGINS-OPTAAD-00165__20160527__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00185': ['CGINS-OPTAAD-00185__20141213.csv',
#   'CGINS-OPTAAD-00185__20141213__CC_taarray.ext',
#   'CGINS-OPTAAD-00185__20141213__CC_tcarray.ext',
#   'CGINS-OPTAAD-00185__20150507.csv',
#   'CGINS-OPTAAD-00185__20150507__CC_taarray.ext',
#   'CGINS-OPTAAD-00185__20150507__CC_tcarray.ext',
#   'CGINS-OPTAAD-00185__20160528.csv',
#   'CGINS-OPTAAD-00185__20160528__CC_taarray.ext',
#   'CGINS-OPTAAD-00185__20160528__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00187': ['CGINS-OPTAAD-00187__20141214.csv',
#   'CGINS-OPTAAD-00187__20141214__CC_taarray.ext',
#   'CGINS-OPTAAD-00187__20141214__CC_tcarray.ext',
#   'CGINS-OPTAAD-00187__20161027.csv',
#   'CGINS-OPTAAD-00187__20161027__CC_taarray.ext',
#   'CGINS-OPTAAD-00187__20161027__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00189': ['CGINS-OPTAAD-00189__20141212.csv',
#   'CGINS-OPTAAD-00189__20141212__CC_taarray.ext',
#   'CGINS-OPTAAD-00189__20141212__CC_tcarray.ext',
#   'CGINS-OPTAAD-00189__20160527.csv',
#   'CGINS-OPTAAD-00189__20160527__CC_taarray.ext',
#   'CGINS-OPTAAD-00189__20160527__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00193': ['CGINS-OPTAAD-00193__20150509.csv',
#   'CGINS-OPTAAD-00193__20150509__CC_taarray.ext',
#   'CGINS-OPTAAD-00193__20150509__CC_tcarray.ext',
#   'CGINS-OPTAAD-00193__20161027.csv',
#   'CGINS-OPTAAD-00193__20161027__CC_taarray.ext',
#   'CGINS-OPTAAD-00193__20161027__CC_tcarray.ext',
#   'CGINS-OPTAAD-00193__20181008.csv',
#   'CGINS-OPTAAD-00193__20181008__CC_taarray.ext',
#   'CGINS-OPTAAD-00193__20181008__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00205': ['CGINS-OPTAAD-00205__20150218.csv',
#   'CGINS-OPTAAD-00205__20150218__CC_taarray.ext',
#   'CGINS-OPTAAD-00205__20150218__CC_tcarray.ext',
#   'CGINS-OPTAAD-00205__20180124.csv',
#   'CGINS-OPTAAD-00205__20180124__CC_taarray.ext',
#   'CGINS-OPTAAD-00205__20180124__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00206': ['CGINS-OPTAAD-00206__20150218.csv',
#   'CGINS-OPTAAD-00206__20150218__CC_taarray.ext',
#   'CGINS-OPTAAD-00206__20150218__CC_tcarray.ext',
#   'CGINS-OPTAAD-00206__20161012.csv',
#   'CGINS-OPTAAD-00206__20161012__CC_taarray.ext',
#   'CGINS-OPTAAD-00206__20161012__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00207': ['CGINS-OPTAAD-00207__20150315.csv',
#   'CGINS-OPTAAD-00207__20150315__CC_taarray.ext',
#   'CGINS-OPTAAD-00207__20150315__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00209': ['CGINS-OPTAAD-00209__20150315.csv',
#   'CGINS-OPTAAD-00209__20150315__CC_taarray.ext',
#   'CGINS-OPTAAD-00209__20150315__CC_tcarray.ext',
#   'CGINS-OPTAAD-00209__20161011.csv',
#   'CGINS-OPTAAD-00209__20161011__CC_taarray.ext',
#   'CGINS-OPTAAD-00209__20161011__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00218': ['CGINS-OPTAAD-00218__20151114.csv',
#   'CGINS-OPTAAD-00218__20151114__CC_taarray.ext',
#   'CGINS-OPTAAD-00218__20151114__CC_tcarray.ext',
#   'CGINS-OPTAAD-00218__20181009.csv',
#   'CGINS-OPTAAD-00218__20181009__CC_taarray.ext',
#   'CGINS-OPTAAD-00218__20181009__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00222': ['CGINS-OPTAAD-00222__20150815.csv',
#   'CGINS-OPTAAD-00222__20150815__CC_taarray.ext',
#   'CGINS-OPTAAD-00222__20150815__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00240': ['CGINS-OPTAAD-00240__20150509.csv',
#   'CGINS-OPTAAD-00240__20150509__CC_taarray.ext',
#   'CGINS-OPTAAD-00240__20150509__CC_tcarray.ext',
#   'CGINS-OPTAAD-00240__20160710.csv',
#   'CGINS-OPTAAD-00240__20160710__CC_taarray.ext',
#   'CGINS-OPTAAD-00240__20160710__CC_tcarray.ext',
#   'CGINS-OPTAAD-00240__20180312.csv',
#   'CGINS-OPTAAD-00240__20180312__CC_taarray.ext',
#   'CGINS-OPTAAD-00240__20180312__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00241': ['CGINS-OPTAAD-00241__20150509.csv',
#   'CGINS-OPTAAD-00241__20150509__CC_taarray.ext',
#   'CGINS-OPTAAD-00241__20150509__CC_tcarray.ext',
#   'CGINS-OPTAAD-00241__20160513.csv',
#   'CGINS-OPTAAD-00241__20160513__CC_taarray.ext',
#   'CGINS-OPTAAD-00241__20160513__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00242': ['CGINS-OPTAAD-00242__20150815.csv',
#   'CGINS-OPTAAD-00242__20150815__CC_taarray.ext',
#   'CGINS-OPTAAD-00242__20150815__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00245': ['CGINS-OPTAAD-00245__20151114.csv',
#   'CGINS-OPTAAD-00245__20151114__CC_taarray.ext',
#   'CGINS-OPTAAD-00245__20151114__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00254': ['CGINS-OPTAAD-00254__20151214.csv',
#   'CGINS-OPTAAD-00254__20151214__CC_taarray.ext',
#   'CGINS-OPTAAD-00254__20151214__CC_tcarray.ext',
#   'CGINS-OPTAAD-00254__20180517.csv',
#   'CGINS-OPTAAD-00254__20180517__CC_taarray.ext',
#   'CGINS-OPTAAD-00254__20180517__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00255': ['CGINS-OPTAAD-00255__20151214.csv',
#   'CGINS-OPTAAD-00255__20151214__CC_taarray.ext',
#   'CGINS-OPTAAD-00255__20151214__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00256': ['CGINS-OPTAAD-00256__20151022.csv',
#   'CGINS-OPTAAD-00256__20151022__CC_taarray.ext',
#   'CGINS-OPTAAD-00256__20151022__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00257': ['CGINS-OPTAAD-00257__20151021.csv',
#   'CGINS-OPTAAD-00257__20151021__CC_taarray.ext',
#   'CGINS-OPTAAD-00257__20151021__CC_tcarray.ext',
#   'CGINS-OPTAAD-00257__20161011.csv',
#   'CGINS-OPTAAD-00257__20161011__CC_taarray.ext',
#   'CGINS-OPTAAD-00257__20161011__CC_tcarray.ext']}

# %% [markdown]
# **=======================================================================================================================**
# Get the serial numbers of the instruments and match them to the UIDs:

# %%
serial_dict = {}
for uid in uids:
    sn = OPTAA[OPTAA['UID'] == uid]['Supplier\nSerial Number']
    serial_dict.update({uid: str(sn.iloc[0])})

# %%
serial_dict
# Out:
# {'CGINS-OPTAAD-00123': '123',
#  'CGINS-OPTAAD-00129': '129',
#  'CGINS-OPTAAD-00130': '130',
#  'CGINS-OPTAAD-00150': '150',
#  'CGINS-OPTAAD-00151': '151',
#  'CGINS-OPTAAD-00152': '152',
#  'CGINS-OPTAAD-00153': '153',
#  'CGINS-OPTAAD-00159': '159',
#  'CGINS-OPTAAD-00165': '165',
#  'CGINS-OPTAAD-00185': '185',
#  'CGINS-OPTAAD-00187': '187',
#  'CGINS-OPTAAD-00189': '189',
#  'CGINS-OPTAAD-00193': '193',
#  'CGINS-OPTAAD-00205': '205',
#  'CGINS-OPTAAD-00206': '206',
#  'CGINS-OPTAAD-00207': '207',
#  'CGINS-OPTAAD-00209': '209',
#  'CGINS-OPTAAD-00218': '218',
#  'CGINS-OPTAAD-00222': '222',
#  'CGINS-OPTAAD-00240': '240',
#  'CGINS-OPTAAD-00241': '241',
#  'CGINS-OPTAAD-00242': '242',
#  'CGINS-OPTAAD-00245': '245',
#  'CGINS-OPTAAD-00254': '254',
#  'CGINS-OPTAAD-00255': '255',
#  'CGINS-OPTAAD-00256': '256',
#  'CGINS-OPTAAD-00257': '257'}

# %% [markdown]
# **=======================================================================================================================**
# The OPTAA QCT capture files are stored with the following Document Control Numbers (DCNs): 3305-00113-XXXXX. Most are storead as **.dat** files which are easy to parse and decode (same formatting as the **.dev** files). However, some are stored as Excel (**.xlsx**) files, which are much trickier to parse.

# %%
files = [file for file in os.listdir(doc_directory) if 'A' in file or 'B' in file]
qct_files = []
for file in files:
    if '113' in file:
        qct_files.append(file)
    else:
        pass

# %%
qct_dict = {}
for uid in uids:
    # Get the QCT Document numbers from the asset tracking sheet
    OPTAA['UID_match'] = OPTAA['UID'].apply(lambda x: True if uid in x else False)
    qct_series = OPTAA[OPTAA['UID_match'] == True]['QCT Testing']
    qct_series = list(qct_series.iloc[0].split('\n'))
    qct_dict.update({uid:qct_series})
qct_paths = {}
for uid in sorted(qct_dict.keys()):
    paths = []
    for file in qct_dict.get(uid):
        path = generate_file_path(doc_directory, file, ext=['.dat','.xlsx'])
        paths.append(path)
    qct_paths.update({uid: paths})

# %%
qct_paths;

# %% [markdown]
# **=======================================================================================================================**
# Get the pre-deployment capture files which have the following DCN: 3305-00313-XXXXX. However, the OPTAA Predeployment procedure does not involve capturing any calibration information. Thus, we do not have any relevant calibration values to test the calibration csvs against.

# %%
for uid in sorted(csv_dict.keys()):
    paths = []
    for file in csv_dict.get(uid):
        path = generate_file_path(asset_management_directory, file, ext=['.csv','.ext'])
        paths.append(path)
    csv_paths.update({uid: paths})

# %%
csv_paths
# Out:
# {'CGINS-OPTAAD-00123': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00123__20131121.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00123__20131121__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00123__20131121__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00123__20151021.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00123__20151021__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00123__20151021__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00129': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00129__20131121.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00129__20131121__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00129__20131121__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00129__20160513.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00129__20160513__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00129__20160513__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00129__20170209.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00129__20170209__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00129__20170209__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00130': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00130__20150509.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00130__20150509__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00130__20150509__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00130__20161125.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00130__20161125__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00130__20161125__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00150': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00150__20140910.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00150__20140910__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00150__20140910__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00150__20161125.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00150__20161125__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00150__20161125__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00151': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00151__20141213.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00151__20141213__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00151__20141213__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00151__20150507.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00151__20150507__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00151__20150507__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00151__20160528.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00151__20160528__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00151__20160528__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00152': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00152__20151023.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00152__20151023__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00152__20151023__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00152__20180711.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00152__20180711__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00152__20180711__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00153': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00153__20140910.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00153__20140910__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00153__20140910__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00153__20161012.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00153__20161012__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00153__20161012__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00159': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00159__20141214.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00159__20141214__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00159__20141214__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00159__20160710.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00159__20160710__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00159__20160710__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00159__20180426.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00159__20180426__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00159__20180426__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00165': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00165__20141212.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00165__20141212__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00165__20141212__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00165__20160527.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00165__20160527__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00165__20160527__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00185': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00185__20141213.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00185__20141213__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00185__20141213__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00185__20150507.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00185__20150507__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00185__20150507__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00185__20160528.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00185__20160528__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00185__20160528__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00187': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00187__20141214.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00187__20141214__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00187__20141214__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00187__20161027.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00187__20161027__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00187__20161027__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00189': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00189__20141212.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00189__20141212__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00189__20141212__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00189__20160527.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00189__20160527__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00189__20160527__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00193': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00193__20150509.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00193__20150509__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00193__20150509__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00193__20161027.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00193__20161027__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00193__20161027__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00193__20181008.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00193__20181008__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00193__20181008__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00205': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00205__20150218.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00205__20150218__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00205__20150218__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00205__20180124.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00205__20180124__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00205__20180124__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00206': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00206__20150218.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00206__20150218__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00206__20150218__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00206__20161012.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00206__20161012__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00206__20161012__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00207': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00207__20150315.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00207__20150315__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00207__20150315__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00209': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00209__20150315.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00209__20150315__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00209__20150315__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00209__20161011.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00209__20161011__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00209__20161011__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00218': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00218__20151114.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00218__20151114__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00218__20151114__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00218__20181009.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00218__20181009__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00218__20181009__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00222': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00222__20150815.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00222__20150815__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00222__20150815__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00240': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00240__20150509.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00240__20150509__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00240__20150509__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00240__20160710.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00240__20160710__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00240__20160710__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00240__20180312.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00240__20180312__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00240__20180312__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00241': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00241__20150509.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00241__20150509__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00241__20150509__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00241__20160513.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00241__20160513__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00241__20160513__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00242': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00242__20150815.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00242__20150815__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00242__20150815__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00245': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00245__20151114.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00245__20151114__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00245__20151114__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00254': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00254__20151214.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00254__20151214__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00254__20151214__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00254__20180517.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00254__20180517__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00254__20180517__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00255': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00255__20151214.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00255__20151214__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00255__20151214__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00256': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00256__20151022.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00256__20151022__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00256__20151022__CC_tcarray.ext'],
#  'CGINS-OPTAAD-00257': ['/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00257__20151021.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00257__20151021__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00257__20151021__CC_tcarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00257__20161011.csv',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00257__20161011__CC_taarray.ext',
#   '/home/andrew/Documents/OOI-CGSN/ooi-integration/asset-management/calibration/OPTAAD/CGINS-OPTAAD-00257__20161011__CC_tcarray.ext']}

# %% [markdown]
# **=======================================================================================================================** Find and return the calibration files which contain vendor supplied calibration information. This is achieved by searching the calibration directories and matching serial numbers to UIDs:

# %%
serial_nums = get_serial_nums(OPTAA, uids)

# %%
cal_dict = get_calibration_files(serial_nums, cal_directory)

# %%
cal_paths = {}
for uid in sorted(cal_dict.keys()):
    paths = []
    for file in cal_dict.get(uid):
        path = generate_file_path(cal_directory, file, ext=['.zip','.cap', '.txt', '.log'])
        paths.append(path)
    cal_paths.update({uid: paths})

# %%
cal_paths;

# %% [markdown]
# **=======================================================================================================================**
# # Parsing Calibration Coefficients
# Above, we have worked through identifying and mapping the calibration files, pre-deployment files, and post-deployment files to the individual instruments through their UIDs and serial numbers. The next step is to open the relevant files and parse out the calibration coefficients. This will require writing a parser for the NUTNRs, including sub-functions to handle the different characteristics of the ISUS and SUNA instruments.
#
# Start by opening the calibration files and read the data:

# %%
class OPTAACalibration():
    # Class that stores calibration values for CTDs.

    def __init__(self, uid):
        self.serial = None
        self.nbins = None
        self.uid = uid
        self.sigfig = 6
        self.date = []
        self.coefficients = {
            'CC_acwo': [],
            'CC_awlngth': [],
            'CC_ccwo': [],
            'CC_cwlngth': [],
            'CC_taarray': 'SheetRef:CC_taarray',
            'CC_tbins': [],
            'CC_tcal': [],
            'CC_tcarray': 'SheetRef:CC_tcarray'
        }
        self.tcarray = []
        self.taarray = []
        self.notes = {
            'CC_acwo': '',
            'CC_awlngth': '',
            'CC_ccwo': '',
            'CC_cwlngth': '',
            'CC_taarray': '',
            'CC_tbins': '',
            'CC_tcal': '',
            'CC_taarray': ''
        }

    @property
    def uid(self):
        return self._uid

    @uid.setter
    def uid(self, d):
        r = re.compile('.{5}-.{6}-.{5}')
        if r.match(d) is not None:
            self._uid = d
            serial = d.split('-')[-1].lstrip('0')
            self.serial = 'ACS-' + serial
        else:
            raise Exception(f"The instrument uid {d} is not a valid uid. Please check.")

            
    def load_cal(self, filepath):
        """
        Wrapper function to load all of the calibration coefficients
        
        Args:
            filepath - path to the directory with filename which has the
                calibration coefficients to be parsed and loaded
        Calls:
            open_cal
            parse_cal
        """
        
        data = self.open_dev(filepath)
        
        self.parse_dev(data)
    
    
    def open_dev(self, filepath):
        """
        Function that opens and reads in cal file
        information for a OPTAA. Zipfiles are acceptable inputs.
        """
        
        if filepath.endswith('.zip'):
            with ZipFile(filepath) as zfile:
                # Check if OPTAA has the .dev file
                filename = [name for name in zfile.namelist() if name.lower().endswith('.dev')]
                
                # Get and open the latest calibration file
                if len(filename) == 1:
                    data = zfile.read(filename[0]).decode('ascii')
                    self.source_file(filepath, filename[0])
                    
                elif len(filename) > 1:
                    raise FileExistsError(f"Multiple .dev files found in {filepath}.")

                else:
                    raise FileNotFoundError(f"No .dev file found in {filepath}.")
                        
        elif filepath.lower().endswith('.dev'):
                with open(filepath) as file:
                    data = file.read()
                self.source_file(filepath, file)
        else:
            raise FileNotFoundError(f"No .dev file found in {filepath}.")
        
        return data


    def source_file(self, filepath, filename):
        """
        Routine which parses out the source file and filename
        where the calibration coefficients are sourced from.
        """
        
        if filepath.lower().endswith('.dev'):
            dcn = filepath.split('/')[-2]
            filename = filepath.split('/')[-1]
        else:
            dcn = filepath.split('/')[-1]
        
        self.source = f'Source file: {dcn} > {filename}'
        

    def parse_dev(self, data):
        """
        Function to parse the .dev file in order to load the
        calibration coefficients for the OPTAA.
        
        Args:
            data - opened .dev file in ascii-format
        """
        
        for line in data.splitlines():
            # Split the data based on data -> header split
            parts = line.split(';')
                # If the len isn't number 2, 
            if len(parts) is not 2:
                # Find the calibration temperature and date
                if 'tcal' in line:
                    line = ''.join((x for x in line if x not in [y for y in string.punctuation if y is not '/']))
                    parts = line.split()
                    # Calibration temperature
                    tcal = float(parts[1])
                    self.coefficients['CC_tcal'] = tcal
                    # Calibration date
                    date = parts[-1].strip(string.punctuation)
                    self.date = pd.to_datetime(date).strftime('%Y%m%d')
        
            else:
                info, comment = parts
                
                if comment.strip().startswith('temperature bins'):
                    tbins = [float(x) for x in info.split()]
                    self.coefficients['CC_tbins'] = tbins
                    
                elif comment.strip().startswith('number'):
                    self.nbins = int(info)
                    
                elif comment.strip().startswith('C'):
                    if self.nbins is None:
                        raise AttributeError(f'Failed to load number of temperature bins.')
                        
                    # Parse out the different calibration coefficients
                    parts = info.split()
                    cwlngth = float(parts[0][1:])
                    awlngth = float(parts[1][1:])
                    ccwo = float(parts[3])
                    acwo = float(parts[4])
                    tcrow = [float(x) for x in parts[5:self.nbins+5]]
                    acrow = [float(x) for x in parts[self.nbins+5:2*self.nbins+5]]
                
                    # Now put the coefficients into the coefficients dictionary
                    self.coefficients['CC_acwo'].append(acwo)
                    self.coefficients['CC_awlngth'].append(awlngth)
                    self.coefficients['CC_ccwo'].append(ccwo)
                    self.coefficients['CC_cwlngth'].append(cwlngth)
                    self.tcarray.append(tcrow)
                    self.taarray.append(acrow)
    
                        
    def write_csv(self, outpath):
        """
        This function writes the correctly named csv file for the ctd to the
        specified directory.

        Args:
            outpath - directory path of where to write the csv file
        Raises:
            ValueError - raised if the CTD object's coefficient dictionary
                has not been populated
        Returns:
            self.to_csv - a csv of the calibration coefficients which is
                written to the specified directory from the outpath.
        """

        # Run a check that the coefficients have actually been loaded
        if len(self.coefficients.values()) <= 2:
            raise ValueError('No calibration coefficients have been loaded.')

        # Create a dataframe to write to the csv
        data = {
            'serial': [self.serial]*len(self.coefficients),
            'name': list(self.coefficients.keys()),
            'value': list(self.coefficients.values())
        }
        df = pd.DataFrame().from_dict(data)
      
        # Now merge the coefficients dataframe with the notes
        notes = pd.DataFrame().from_dict({
            'name':list(self.notes.keys()),
            'notes':list(self.notes.values())
        })
        df = df.merge(notes, how='outer', left_on='name', right_on='name')
            
        # Add in the source file
        df['notes'].iloc[0] = df['notes'].iloc[0] + ' ' + self.source
        
        # Sort the data by the coefficient name
        df = df.sort_values(by='name')

        # Generate the csv names
        csv_name = self.uid + '__' + self.date + '.csv'
        tca_name = self.uid + '__' + self.date + '__' + 'CC_tcarray.ext'
        taa_name = self.uid + '__' + self.date + '__' + 'CC_taarray.ext'
        
        def write_array(filename, cal_array):
            with open(filename, 'w') as out:
                array_writer = csv.writer(out)
                array_writer.writerows(cal_array)

        # Write the dataframe to a csv file
        check = input(f"Write {csv_name} to {outpath}? [y/n]: ")
        # check = 'y'
        if check.lower().strip() == 'y':
            df.to_csv(outpath+'/'+csv_name, index=False)
            write_array(outpath+'/'+tca_name, self.tcarray)
            write_array(outpath+'/'+taa_name, self.taarray)

# %%
optaa = OPTAACalibration(uid=uid)

# %%
optaa.load_cal(cal_paths[uid][0])

# %%
optaa.date
# Out:
# '20121128'

# %%
optaa.coefficients
# Out:
# {'CC_acwo': [-0.465231,
#   -0.274376,
#   -0.131399,
#   -0.024706,
#   0.058295,
#   0.126055,
#   0.185656,
#   0.240417,
#   0.289584,
#   0.33791,
#   0.381069,
#   0.423962,
#   0.465806,
#   0.505779,
#   0.544813,
#   0.582403,
#   0.618499,
#   0.653872,
#   0.687644,
#   0.720226,
#   0.751347,
#   0.78086,
#   0.808414,
#   0.834566,
#   0.860689,
#   0.886948,
#   0.913385,
#   0.938929,
#   0.963533,
#   0.987193,
#   1.009682,
#   1.031291,
#   1.052552,
#   1.07342,
#   1.093032,
#   1.110473,
#   1.124673,
#   1.134672,
#   1.140164,
#   1.140155,
#   1.134724,
#   1.12522,
#   1.111056,
#   1.10325,
#   1.102718,
#   1.109283,
#   1.119172,
#   1.130082,
#   1.140827,
#   1.151058,
#   1.160595,
#   1.168841,
#   1.174887,
#   1.177852,
#   1.178076,
#   1.176677,
#   1.17593,
#   1.177861,
#   1.181059,
#   1.18391,
#   1.183523,
#   1.178057,
#   1.165895,
#   1.145849,
#   1.11669,
#   1.076874,
#   1.025265,
#   0.96053,
#   0.880828,
#   0.784785,
#   0.669853,
#   0.535218,
#   0.382249,
#   0.215282,
#   0.04013,
#   -0.13566,
#   -0.30612,
#   -0.460697,
#   -0.588048,
#   -0.685993,
#   -0.75626,
#   -0.803541,
#   -0.836111],
#  'CC_awlngth': [401.0,
#   405.1,
#   409.3,
#   413.2,
#   417.4,
#   422.2,
#   427.0,
#   431.7,
#   435.9,
#   440.5,
#   444.9,
#   449.7,
#   454.4,
#   459.0,
#   463.6,
#   468.5,
#   473.8,
#   478.9,
#   483.8,
#   488.6,
#   493.0,
#   497.7,
#   502.6,
#   507.8,
#   513.0,
#   518.2,
#   523.5,
#   528.2,
#   532.9,
#   537.7,
#   542.5,
#   547.5,
#   552.2,
#   557.4,
#   562.5,
#   567.3,
#   571.3,
#   575.8,
#   579.8,
#   583.9,
#   588.0,
#   592.2,
#   597.1,
#   601.9,
#   606.5,
#   611.2,
#   615.7,
#   620.5,
#   624.9,
#   629.0,
#   633.5,
#   637.8,
#   642.1,
#   646.4,
#   650.9,
#   655.4,
#   660.0,
#   664.2,
#   668.8,
#   673.1,
#   677.2,
#   681.2,
#   685.0,
#   688.9,
#   692.3,
#   695.8,
#   699.4,
#   702.9,
#   706.0,
#   709.7,
#   712.9,
#   716.1,
#   719.3,
#   722.4,
#   725.6,
#   728.6,
#   731.5,
#   734.2,
#   736.4,
#   739.6,
#   741.9,
#   744.2,
#   746.5],
#  'CC_ccwo': [0.449779,
#   0.538688,
#   0.617422,
#   0.682801,
#   0.74298,
#   0.795652,
#   0.843262,
#   0.887441,
#   0.938646,
#   0.968727,
#   0.992966,
#   1.037978,
#   1.065927,
#   1.091827,
#   1.116135,
#   1.139735,
#   1.164184,
#   1.185298,
#   1.204736,
#   1.224225,
#   1.24263,
#   1.26041,
#   1.275087,
#   1.290111,
#   1.302759,
#   1.315274,
#   1.327853,
#   1.339196,
#   1.350865,
#   1.360752,
#   1.370812,
#   1.382231,
#   1.395091,
#   1.399982,
#   1.41012,
#   1.418816,
#   1.424262,
#   1.42733,
#   1.426671,
#   1.42213,
#   1.413418,
#   1.400162,
#   1.377522,
#   1.356663,
#   1.337731,
#   1.325156,
#   1.320927,
#   1.322257,
#   1.3246,
#   1.326433,
#   1.328311,
#   1.329881,
#   1.330223,
#   1.328659,
#   1.324227,
#   1.317686,
#   1.308952,
#   1.300103,
#   1.29344,
#   1.291371,
#   1.288168,
#   1.283102,
#   1.270476,
#   1.268457,
#   1.243269,
#   1.213635,
#   1.177116,
#   1.128387,
#   1.068318,
#   0.994642,
#   0.905692,
#   0.799527,
#   0.674534,
#   0.530819,
#   0.369682,
#   0.196874,
#   0.024024,
#   -0.163795,
#   -0.329299,
#   -0.476916,
#   -0.599358,
#   -0.6905,
#   -0.755437],
#  'CC_cwlngth': [400.1,
#   404.3,
#   408.4,
#   412.1,
#   416.2,
#   421.0,
#   425.8,
#   429.9,
#   434.3,
#   438.2,
#   443.0,
#   447.6,
#   452.3,
#   456.9,
#   461.3,
#   465.7,
#   470.8,
#   476.1,
#   481.1,
#   485.7,
#   490.2,
#   494.8,
#   499.3,
#   504.0,
#   509.4,
#   514.7,
#   520.1,
#   524.8,
#   529.2,
#   533.9,
#   538.5,
#   543.3,
#   548.1,
#   553.1,
#   558.1,
#   562.8,
#   567.3,
#   571.9,
#   576.1,
#   580.2,
#   584.1,
#   588.0,
#   592.0,
#   596.4,
#   600.8,
#   605.5,
#   610.2,
#   614.8,
#   619.4,
#   623.9,
#   628.2,
#   632.4,
#   636.7,
#   641.0,
#   645.3,
#   649.6,
#   654.0,
#   658.3,
#   662.8,
#   667.2,
#   671.3,
#   675.5,
#   679.6,
#   683.3,
#   687.1,
#   691.0,
#   694.5,
#   697.8,
#   701.3,
#   704.9,
#   708.3,
#   711.3,
#   714.4,
#   717.4,
#   720.6,
#   723.6,
#   726.7,
#   729.4,
#   732.6,
#   735.1,
#   737.5,
#   740.5,
#   742.9],
#  'CC_taarray': 'SheetRef:CC_taarray',
#  'CC_tbins': [3.684881,
#   4.425816,
#   5.55977,
#   6.46719,
#   7.474765,
#   8.465398,
#   9.494947,
#   10.487692,
#   11.513433,
#   12.496269,
#   13.495652,
#   14.503188,
#   15.514706,
#   16.475176,
#   17.473571,
#   18.484565,
#   19.499048,
#   20.515,
#   21.505616,
#   22.480588,
#   23.491356,
#   24.468113,
#   25.477,
#   26.475909,
#   27.497073,
#   28.485,
#   29.487143,
#   30.498437,
#   31.495938,
#   32.505484,
#   33.498276,
#   34.502414,
#   35.50125,
#   36.644464,
#   37.0052],
#  'CC_tcal': 19.0,
#  'CC_tcarray': 'SheetRef:CC_tcarray'}

# %%
optaa.serial
# Out:
# 'ACS-123'

# %%
temp_directory = '/'.join((os.getcwd(),'temp'))

# %%
if os.path.isdir(temp_directory):
    shutil.rmtree(temp_directory)
    ensure_dir(temp_directory)
else:
    ensure_dir(temp_directory)

# %%
optaa.write_csv(temp_directory)
# Out:
# Write CGINS-OPTAAD-00123__20121128.csv to /home/andrew/Documents/OOI-CGSN/QAQC_Sandbox/Metadata_Review/temp? [y/n]: y

# %%
os.listdir(temp_directory)
# Out:
# ['CGINS-OPTAAD-00123__20121128__CC_taarray.ext',
#  'CGINS-OPTAAD-00123__20121128__CC_tcarray.ext',
#  'CGINS-OPTAAD-00123__20121128.csv']

# %%
df_optaa = pd.read_csv(temp_directory+'/'+'CGINS-OPTAAD-00123__20121128.csv')
with open(temp_directory+'/'+'CGINS-OPTAAD-00123__20121128__CC_tcarray.ext') as file:
    tcarray = file.read()
with open(temp_directory+'/'+'CGINS-OPTAAD-00123__20121128__CC_taarray.ext') as file:
    taarray = file.read()

# %%
df_optaa
# Out:
#     serial        name                                              value  \
# 0  ACS-123     CC_acwo  [-0.465231, -0.274376, -0.131399, -0.024706, 0...
# 1  ACS-123  CC_awlngth  [401.0, 405.1, 409.3, 413.2, 417.4, 422.2, 427...
# 2  ACS-123     CC_ccwo  [0.449779, 0.538688, 0.617422, 0.682801, 0.742...
# 3  ACS-123  CC_cwlngth  [400.1, 404.3, 408.4, 412.1, 416.2, 421.0, 425...
# 4  ACS-123  CC_taarray                                SheetRef:CC_taarray
# 5  ACS-123    CC_tbins  [3.684881, 4.425816, 5.55977, 6.46719, 7.47476...
# 6  ACS-123     CC_tcal                                               19.0
# 7  ACS-123  CC_tcarray                                SheetRef:CC_tcarray
#
#                                                notes
# 0   Source file: OPTAA-D_AC-S_SN_123_Calibration_...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN

# %%
df_optaa['notes'].iloc[0]
# Out:
# ' Source file: OPTAA-D_AC-S_SN_123_Calibration_Files.zip > acs123.dev'

# %%
optaa.coefficients['CC_tcal'][0]
# Out:
# 19.0

# %% [markdown]
# **=======================================================================================================================**
# # Source Loading of Calibration Coefficients
# With an OPTAA Calibration object created, we can now begin parsing the different calibration sources for each OPTAA. We will then compare all of the calibration values from each of the sources, checking for any discrepancies between them.

# %% [markdown]
# Below, I plan on going through each of the NUTNR UIDs, and parse the data into csvs. For sources which contain multiple sources, I plan on extracting each of the calibrations to a temporary folder using the following structure:
#
#     <local working directory>/<temp>/<source>/data/<calibration file>
#
# The separate calibrations will be saved using the standard UFrame naming convention with the following directory structure:
#
#     <local working directory>/<temp>/<source>/<calibration csv>
#
# The csvs themselves will also be copied to the temporary folder. This allows for the program to be looking into the same temp directory for every NUTNR check.

# %%
uid = uids[0]

# %%
temp_directory = '/'.join((os.getcwd(),'temp'))
# Check if the temp directory exists; if it already does, purge and rewrite
if os.path.exists(temp_directory):
    shutil.rmtree(temp_directory)
    ensure_dir(temp_directory)

# %% [markdown]
# Copy the existing csvs from asset management to the temp directory:

# %%
for path in csv_paths[uid]:
    savedir = '/'.join((temp_directory,'csv'))
    ensure_dir(savedir)
    savepath = '/'.join((savedir, path.split('/')[-1]))
    shutil.copyfile(path, savepath)

# %%
os.listdir(temp_directory+'/csv')
# Out:
# ['CGINS-OPTAAD-00123__20151021__CC_taarray.ext',
#  'CGINS-OPTAAD-00123__20151021.csv',
#  'CGINS-OPTAAD-00123__20131121.csv',
#  'CGINS-OPTAAD-00123__20151021__CC_tcarray.ext',
#  'CGINS-OPTAAD-00123__20131121__CC_tcarray.ext',
#  'CGINS-OPTAAD-00123__20131121__CC_taarray.ext']

# %% [markdown]
# **=======================================================================================================================**
# Load the calibration coefficients from the vendor calibration source files. Start by extracting or copying them to the source data folder in the temporary directory.

# %%
cal_paths[uid]
# Out:
# ['/media/andrew/OS/Users/areed/Documents/Project_Files/Records/Instrument_Records/OPTAA/OPTAA_Cal/OPTAA-D_AC-S_SN_123_Calibration_Files.zip',
#  '/media/andrew/OS/Users/areed/Documents/Project_Files/Records/Instrument_Records/OPTAA/OPTAA_Cal/OPTAA-D_AC-S_SN_123_Calibration_Files_2013-07-17.zip',
#  '/media/andrew/OS/Users/areed/Documents/Project_Files/Records/Instrument_Records/OPTAA/OPTAA_Cal/OPTAA-D_AC-S_SN_123_Calibration_Files_2015-07-20.zip',
#  '/media/andrew/OS/Users/areed/Documents/Project_Files/Records/Instrument_Records/OPTAA/OPTAA_Cal/OPTAA-D_AC-S_SN_123_Calibration_Files_2016-09-29.zip']

# %% [markdown]
# Extract the calibration zip files to the local temp directory:

# %%
for path in cal_paths[uid]:
    with ZipFile(path) as zfile:
        files = [name for name in zfile.namelist() if name.lower().endswith('.dev')]
        for file in files:
            exdir = path.split('/')[-1].strip('.zip')
            expath = '/'.join((temp_directory,'cal','data',exdir))
            ensure_dir(expath)
            zfile.extract(file,path=expath)

# %%
os.listdir(temp_directory+'/cal/data/OPTAA-D_AC-S_SN_123_Calibration_Files_2016-09-29')
# Out:
# ['acs123.dev']

# %% [markdown]
# Write the vendor calibration files to csvs following the UFrame convention:

# %%
savedir = '/'.join((temp_directory,'cal'))
ensure_dir(savedir)
# Now parse the calibration coefficients
for dirpath, dirnames, filenames in os.walk('/'.join((temp_directory,'cal','data'))):
    for file in filenames:
        filepath = os.path.join(dirpath, file)
        # With the filepath for the given calibration retrived, I can now start an instance of the NUTNR Calibration
        # object and begin parsing the coefficients
        optaa = OPTAACalibration(uid)
        optaa.load_cal(filepath)
        optaa.write_csv(savedir)
# Out:
# Write CGINS-OPTAAD-00123__20160929.csv to /home/andrew/Documents/OOI-CGSN/QAQC_Sandbox/Metadata_Review/temp/cal? [y/n]: y
# Write CGINS-OPTAAD-00123__20150701.csv to /home/andrew/Documents/OOI-CGSN/QAQC_Sandbox/Metadata_Review/temp/cal? [y/n]: y
# Write CGINS-OPTAAD-00123__20121128.csv to /home/andrew/Documents/OOI-CGSN/QAQC_Sandbox/Metadata_Review/temp/cal? [y/n]: y
# Write CGINS-OPTAAD-00123__20130716.csv to /home/andrew/Documents/OOI-CGSN/QAQC_Sandbox/Metadata_Review/temp/cal? [y/n]: y

# %% [markdown]
# **=======================================================================================================================**
# # Calibration Coefficient Comparison
# We have now successfully parsed the calibration files from all the possible sources: the vendor calibration files, the pre-deployments files, and the post-deployment files. Furthermore, we have saved csvs in the UFrame format for all of these calibrations. Now, we want to load those csvs into pandas dataframes, which allow for easy element-by-element comparison of calibration coefficients.
