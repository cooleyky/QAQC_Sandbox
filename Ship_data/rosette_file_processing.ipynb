# %% [markdown]
# # Water Sampling Processing Script
# ### Author: Andrew Reed, CGSN - WHOI
#
# ### Motivation
# The motivation for this script is to automate producing the bottle files in a consistent, easily parseable manner consistent with SeaBird's naming and processing scheme. I chose to take this approach after attempting to parse the bottle (.btl) files output from SeaBird's SeaSoft V2 processing software. Unfortunately, SeaBird outputs into a tab-deliminated text format with inconsistent spacing between columns and spacing offsets. This prevents simple alignment of column names:column values and makes parsing column names more difficult without a priori knowing where parsing issues will arise.
#
# ### Approach
# I chose to utilize the rosette (.ros) files produced by SeaBird's SeaSoft V2 software as part of the initial conversion of their propietary .cnv formatted data produced by their CTDs and rosettes. The .ros files have explicit column naming outlined in the header of the file, and the columns with the parameter values are consistently spaced. This allows for an easy mapping of the column name to column values based on location.
#
# Additionally, I use a secondary file which outlines the parameter "short names" to the parameter "full names + units." This information is from SeaBird's SeaSoft V2 manual. Additionally, the processing method of taking the mean of all scans per bottle firing also follows the procedure outlined in the SeaSoft manual.
#
# ### Usage
# To use this software for your own processing, the following pacakges need to be installed:
# * Pandas
# * Numpy
#
# Additionally, you will need to change the filepaths to the appropriate directory locations on your local machine. Once that is complete, simply run the cells in order. The software will write the results to the directroy where the rosette files are stored.
#
# **Note**: The ".btl" files produced here are meant for ease-of-use in producing our water sample summary sheets. They will not work for continued processing to get derived variables using SeaBird's software.

# %%
# Import packages used in this notebook
import os, sys
import pandas as pd
import numpy as np

# %%
basepath = 'C:/Users/areed/Documents/OOI-CGSN/QAQC_Sandbox/Ship_data/'

# %%
# Load the name mapping for the column names
sbe_name_map = pd.read_excel('C:/Users/areed/Documents/OOI-CGSN/QAQC_Sandbox/Reference_Files/seabird_ctd_name_map.xlsx')
sbe_name_map
# Out:
#        Short Name                                          Full Name  \
# 0            accM                               Acceleration [m/s^2]
# 1            accF                              Acceleration [ft/s^2]
# 2            altM                                      Altimeter [m]
# 3            altF                                     Altimeter [ft]
# 4         avgsvCM         Average Sound Velocity [Chen-Millero, m/s]
# 5         avgsvCF        Average Sound Velocity [Chen-Millero, ft/s]
# 6         avgsvDM            Average Sound Velocity [Delgrosso, m/s]
# 7         avgsvDF           Average Sound Velocity [Delgrosso, ft/s]
# 8         avgsvWM               Average Sound Velocity [Wilson, m/s]
# 9         avgsvWF              Average Sound Velocity [Wilson, ft/s]
# 10            bat            Beam Attenuation, Chelsea/Seatech [1/m]
# 11           bat1         Beam Attenuation, Chelsea/Seatech, 2 [1/m]
# 12        batdiff  Beam Attenuation, Chelsea/Seatech/WET Labs CSt...
# 13       wetBAttn               Beam Attenuation, WET Labs AC3 [1/m]
# 14       CStarAt0            Beam Attenuation, WET Labs C-Star [1/m]
# 15       CStarAt1         Beam Attenuation, WET Labs C-Star, 2 [1/m]
# 16       CStarAt2         Beam Attenuation, WET Labs C-Star, 3 [1/m]
# 17       CStarAt3         Beam Attenuation, WET Labs C-Star, 4 [1/m]
# 18       CStarAt4         Beam Attenuation, WET Labs C-Star, 5 [1/m]
# 19       CStarAt5         Beam Attenuation, WET Labs C-Star, 6 [1/m]
# 20    CStarAtDiff  Beam Attenuation, WET Labs C-Star, Diff, 2 - 1...
# 21          xmiss             Beam Transmission, Chelsea/Seatech [%]
# 22         xmiss1          Beam Transmission, Chelsea/Seatech, 2 [%]
# 23      xmissdiff   Beam Transmission, Chelsea/Seatech/WET Labs C...
# 24      wetBTrans                Beam Transmission, WET Labs AC3 [%]
# 25       CStarTr0             Beam Transmission, WET Labs C-Star [%]
# 26       CStarTr1          Beam Transmission, WET Labs C-Star, 2 [%]
# 27       CStarTr2          Beam Transmission, WET Labs C-Star, 3 [%]
# 28       CStarTr3          Beam Transmission, WET Labs C-Star, 4 [%]
# 29       CStarTr4          Beam Transmission, WET Labs C-Star, 5 [%]
# ..            ...                                                ...
# 486       turbWET               Turbidity, WET Labs SeaOWL BB, 2 - 1
# 487  SeaOWLbbdiff               Turbidity, WET Labs SeaOWL BB, 2 - 1
# 488         user1                              User Defined Variable
# 489         user2                           User Defined Variable, 2
# 490         user3                           User Defined Variable, 3
# 491         user4                           User Defined Variable, 4
# 492         user5                           User Defined Variable, 5
# 493        uexpo0                                   User Exponential
# 494        uexpo1                                User Exponential, 2
# 495        uexpo2                                User Exponential, 3
# 496        upoly0                                    User Polynomial
# 497        upoly1                                 User Polynomial, 2
# 498        upoly2                                 User Polynomial, 3
# 499            v0                                          Voltage 0
# 500            v1                                          Voltage 1
# 501            v2                                          Voltage 2
# 502            v3                                          Voltage 3
# 503            v4                                          Voltage 4
# 504            v5                                          Voltage 5
# 505            v6                                          Voltage 6
# 506            v7                                          Voltage 7
# 507            v8                                          Voltage 8
# 508            v9                                          Voltage 9
# 509           v10                                         Voltage 10
# 510           v11                                         Voltage 11
# 511           v12                                         Voltage 12
# 512           v13                                         Voltage 13
# 513           v14                                         Voltage 14
# 514           v15                                         Voltage 15
# 515          zaps                                        Zaps [nmol]
#
#          Friendly Name               Units  \
# 0                acc M               m/s^2
# 1                acc F              ft/s^2
# 2                alt M                   m
# 3                alt F                  ft
# 4            avgsv-C M   Chen-Millero, m/s
# 5            avgsv-C F  Chen-Millero, ft/s
# 6            avgsv-D M      Delgrosso, m/s
# 7            avgsv-D F     Delgrosso, ft/s
# 8            avgsv-W M         Wilson, m/s
# 9            avgsv-W F        Wilson, ft/s
# 10                 bat                 1/m
# 11                bat2                 1/m
# 12             batdiff                 1/m
# 13            wetBAttn                 1/m
# 14             CStarAt                 1/m
# 15            CStarAt2                 1/m
# 16            CStarAt3                 1/m
# 17            CStarAt4                 1/m
# 18            CStarAt5                 1/m
# 19            CStarAt6                 1/m
# 20         CStarAtDiff                 1/m
# 21               xmiss                   %
# 22              xmiss2                   %
# 23           xmissdiff                   %
# 24           wetBTrans                   %
# 25             CStarTr                   %
# 26            CStarTr2                   %
# 27            CStarTr3                   %
# 28          CStarTr4                     %
# 29            CStarTr5                   %
# ..                 ...                 ...
# 486  turbWETSeaOWLdiff            m-1sr -1
# 487  turbWETSeaOWLdiff            m-1sr -1
# 488               user                 NaN
# 489              user2                 NaN
# 490              user3                 NaN
# 491              user4                 NaN
# 492              user5                 NaN
# 493              uexpo                 NaN
# 494             uexpo1                 NaN
# 495             uexpo2                 NaN
# 496              upoly                 NaN
# 497             upoly2                 NaN
# 498             upoly3                 NaN
# 499                 v0                   V
# 500                 v1                   V
# 501                 v2                   V
# 502                 v3                   V
# 503                 v4                   V
# 504                 v5                   V
# 505                 v6                   V
# 506                 v7                   V
# 507                 v8                   V
# 508                 v9                   V
# 509                v10                   V
# 510                v11                   V
# 511                v12                   V
# 512                v13                   V
# 513                v14                   V
# 514                v15                   V
# 515               zaps                nmol
#
#                                         Notes/Comments
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                          1st sensor
# 11                                          2nd sensor
# 12                             2nd sensor - 1st sensor
# 13                                                 NaN
# 14                                          1st sensor
# 15                                          2nd sensor
# 16                                          3rd sensor
# 17                                          4th sensor
# 18                                          5th sensor
# 19                                          6th sensor
# 20                             2nd sensor - 1st sensor
# 21                                          1st sensor
# 22                                          2nd sensor
# 23                             2nd sensor - 1st sensor
# 24                                                 NaN
# 25                                          1st sensor
# 26                                          2nd sensor
# 27                                          3rd sensor
# 28                                          4th sensor
# 29                                          5th sensor
# ..                                                 ...
# 486                         2nd - 1st turbidity sensor
# 487                         2nd - 1st turbidity sensor
# 488  1st sensor; user selects variable name for fil...
# 489  2nd sensor; user selects variable name for fil...
# 490  3rd sensor; user selects variable name for fil...
# 491  4th sensor; user selects variable name for fil...
# 492  5th sensor; user selects variable name for fil...
# 493                        1st user exponential sensor
# 494                        2nd user exponential sensor
# 495                        3rd user exponential sensor
# 496                         1st user polynomial sensor
# 497                         2nd user polynomial sensor
# 498                         3rd user polynomial sensor
# 499                                 1st voltage sensor
# 500                                 2nd voltage sensor
# 501                                 3rd voltage sensor
# 502                                 4th voltage sensor
# 503                                 5th voltage sensor
# 504                                 6th voltage sensor
# 505                                 7th voltage sensor
# 506                                 8th voltage sensor
# 507                                 9th voltage sensor
# 508                                10th voltage sensor
# 509                                11th voltage sensor
# 510                                12th voltage sensor
# 511                                13th voltage sensor
# 512                                14th voltage sensor
# 513                                15th voltage sensor
# 514                                16th voltage sensor
# 515                                                NaN
#
# [516 rows x 5 columns]

# %%
# Load the cruise i.d.
with open('C:/Users/areed/Documents/OOI-CGSN/QAQC_Sandbox/Ship_data/Irminger/Irminger-5/Data/CRUISE_ID') as file:
    cruise_id = file.read().strip()
cruise_id
# Out:
# 'ar30-03'

# %%
def parse_header(header):
    """
    Function to parse the header of a SeaBird rosette file (.ros).
    This takes the place of generating a bottle file (.btl) using
    SeaBird's SeaSoft software.
    
    Args:
        header - a text file containing the relevant header info
    Returns:
        header_dict - a dictionary containing a mapping of the
            column name to its position in the data file
        start_time - the time that the SBE system started recording
        scan_interval - the # of scans per second
    """
    # Initialize the header dictionary
    header_dict = {}
    start_time = []
    scan_interval = []
    for line in header.splitlines():
        if 'name' in line:
            header_index = line.split()[2]
            header_name = line.split()[4].replace(':','')
            header_dict.update({header_name:header_index})
        elif 'interval' in line:
            scan_interval = line.split()[-1]
        elif 'start_time' in line:
            start_time = line.split()[3:7] 
            
    # Return the relevant important data
    return header_dict, start_time, scan_interval

# %%
def parse_data(data,header_dict):
    """
    Parses the data from the rosette file based on the position of the
    column, using the column locations from the header.
    
    Args:
        data - a text file containing the data from the rosette file
        header_dict - a dictionary containing a mapping of column names to the
            column position
    Returns:
        data_dict - a dictionary containing key:value pairs of where key is the
            column position and value is the column values 
    """
    
    # Generate a dictionary for the data with mapping from the column dictionary
    data_dict = {x:[] for x in header_dict.values()}
    
    # Now parse the data
    for line in data.splitlines():
        for i,x in enumerate(line.split()):
            try:
                float(x)
                data_dict[str(i)].append(x)
            except:
                pass
    
    return data_dict

# %%
def generate_btl_data(data_dict, header_dict, start_time, scan_interval):
    """
    Function to generate the equivalent bottle file (.btl).
    
    Args:
        data_dict - a dictionary containing key:value pairs of where key is the
            column position and value is the column values
        header_dict - a dictionary containing a mapping of column names to the
            column position
        start_time - the time that the CTD cast started
        scan_interval - the number of seconds per ctd scan
    Returns:
        df - a pandas dataframe containing the data from the data dictionary 
            with the column names from the header dictionary and the datetime
            calculated from the start_time and the scan_interval
    """
    
    # Using the data and header dictionaries, map the data columns to the
    # appropriate column names
    result = {}
    for key,item in header_dict.items():
        values = data_dict.get(item)
        result.update({key:values})

    # Put the data into a dataframe and convert the data from strings to floats
    df = pd.DataFrame.from_dict(result)
    for column in df.columns.values:
        try:
            df[column] = df[column].apply(lambda x: float(x))
        except:
            pass
    
    # Groupby the dataframe based on bottle name
    df = df.groupby(by='nbf').mean()

    # Convert the scan counts to seconds
    df['scan'] = df['scan'].apply(lambda x: x*float(scan_interval))

    # Add in the date time
    start_time = pd.to_datetime(' '.join(start_time))
    df['Datetime'] = df['scan'].apply(lambda x: start_time + pd.to_timedelta(x,unit='s'))
    df['Datetime'] = df['Datetime'].apply(lambda x: x.strftime('%Y-%m-%dT%H:%M:%S.%fZ'))

    return df

# %%
def parse_cast_number(filename):
    """
    Parses the cast number out of the file name. It assumes that the 
    cast number is 3 numbers long and occurs right before the file
    extension.
    
    Args:
        filename - the name of the file to be parsed
    Returns:
        cast_num - the cast number of the file
    """
    
    index = file.index('.')
    # From the index, count backwards until have 3 numbers for cast
    num = 0
    ind = 0
    while num < 3:
        ind = ind+1
        try:
            float(file[index-ind])
            num = num+1
        except:
            pass
    # Nower return the cast number
    cast_num = file[index-ind:index]
    
    return cast_num

# %%
def process_ros_files(filepath,sbe_name_map,cruise_id):
    """
    Parent function to parse and process SeaBird rosette (.ros)
    files, generate a pandas dataframe, and write bottle (.btl)
    files (as csvs). This takes the place of the bottle processing
    in SeaSoft V2 provided by SeaBird.
    
    Args:
        filepath - directory path to the location of the rosette files
        sbe_name_map - a pandas dataframe containing a mapping of the
            seabird short names to full names. Taken directly from the
            seabird manuals.
        cruise_id - string input of the cruise id
    Calls:
        parse_header
        parse_data
        generate_btl_data
    Returns:
        .btl - writes a bottle file to the same directory location as the
            rosette file.
    """
    
    # First, open the file and read it in
    with open(filepath) as file:
        data = file.read()
        header, data = data.split('*END*')
        
    # Parse the header file
    header_dict, start_time, scan_interval = parse_header(header)
    
    # Parse the data based on the output from the header
    data_dict = parse_data(data, header_dict)
    
    # Create a pandas dataframe
    df = generate_btl_data(data_dict, header_dict, start_time, scan_interval)
    
    # Rename the column title using the sbe_name_mapping 
    for colname in list(df.columns.values):
        try:
            fullname = list(sbe_name_map[sbe_name_map['Short Name'] == colname]['Full Name'])[0]
            df.rename({colname:fullname},axis='columns',inplace=True)
        except:
            pass
    # Rename the index as well
    df.index.rename(list(sbe_name_map[sbe_name_map['Short Name'] == df.index.name]['Full Name'])[0],inplace=True)
    
    # Add in the cruise id
    df['Cruise ID'] = cruise_id
    
    # Parse and add in the cast number
    cast = parse_cast_number(filepath)
    df['Cast'] = cast
    
    # Generate the btl name file
    btl_path = filepath.replace('.ros','.csv')
    
    # Save to the same directory as the rosette files
    df.to_csv(btl_path)

# %%
# Iterating through this process will generate .btl files from the rosette files.
# This is done in lieu of using the SeaBird software processing. I chose this route
# because of inconsistent column spacings made parsing and matching column names to
# column values difficult. The rosette headers make the column relationship explicit.
filepath = 'C:/Users/areed/Documents/OOI-CGSN/QAQC_Sandbox/Ship_data/Irminger/Irminger-5/Data/CTD/'
for file in os.listdir(filepath):
    if '.ros' in file:
        process_ros_files(filepath+file, sbe_name_map, cruise_id)

# %%
btl = pd.read_csv('C:/Users/areed/Documents/OOI-CGSN/QAQC_Sandbox/Ship_data/Irminger/Irminger-5/Data/CTD/ar30-03003.csv')

# %%
btl
# Out:
#     Bottles Fired  Modulo Error Count  Pressure, Digiquartz [db]  \
# 0             1.0                 0.0                2998.401887
# 1             2.0                 0.0                2540.190990
# 2             3.0                 0.0                2029.040691
# 3             4.0                 0.0                1623.636144
# 4             5.0                 0.0                1317.683866
# 5             6.0                 0.0                1014.467856
# 6             7.0                 0.0                 812.846619
# 7             8.0                 0.0                 609.473485
# 8             9.0                 0.0                 407.482876
# 9            10.0                 0.0                 205.654742
# 10           11.0                 0.0                 105.380320
# 11           12.0                 0.0                 105.551763
# 12           13.0                 0.0                  44.902835
# 13           14.0                 0.0                  25.294577
# 14           15.0                 0.0                  15.271845
# 15           16.0                 0.0                   4.701845
# 16           17.0                 0.0                   4.438052
#
#     Depth [salt water, m]  Latitude [deg]  Longitude [deg]  \
# 0             2948.939093       60.889800       -35.355969
# 1             2500.937278       60.889620       -35.354850
# 2             2000.069546       60.889470       -35.353845
# 3             1601.979918       60.889330       -35.352960
# 4             1301.049608       60.889200       -35.352110
# 5             1002.383691       60.889020       -35.350980
# 6              803.550990       60.888824       -35.349666
# 7              602.797412       60.888730       -35.349122
# 8              403.215124       60.888640       -35.348460
# 9              203.599969       60.888500       -35.347760
# 10             104.352639       60.888440       -35.347323
# 11             104.522588       60.888440       -35.347320
# 12              44.471474       60.888400       -35.347041
# 13              25.052753       60.888360       -35.346877
# 14              15.126186       60.888360       -35.346740
# 15               4.657206       60.888279       -35.346180
# 16               4.395856       60.888260       -35.346164
#
#     Temperature [ITS-90, deg C]  Temperature, 2 [ITS-90, deg C]  \
# 0                      1.351952                        1.353832
# 1                      3.005421                        3.006737
# 2                      3.460248                        3.461490
# 3                      3.514286                        3.515012
# 4                      3.374191                        3.374618
# 5                      3.484716                        3.485085
# 6                      3.553446                        3.553530
# 15                               -0.749529  11459.425834   0.0
# 16                               -0.742080  11467.800841   0.0
#
#                        Datetime Cruise ID Cast
# 0   2018-06-07T09:20:35.419620Z   ar30-03    3
# 1   2018-06-07T09:34:14.920276Z   ar30-03    3
# 2   2018-06-07T09:52:04.587798Z   ar30-03    3
# 3   2018-06-07T10:05:07.338424Z   ar30-03    3
# 4   2018-06-07T10:16:09.713954Z   ar30-03    3
# 5   2018-06-07T10:27:12.631151Z   ar30-03    3
# 6   2018-06-07T10:38:52.923378Z   ar30-03    3
# 7   2018-06-07T10:48:09.215490Z   ar30-03    3
# 8   2018-06-07T10:57:27.132603Z   ar30-03    3
# 9   2018-06-07T11:07:03.716397Z   ar30-03    3
# 10  2018-06-07T11:15:03.008448Z   ar30-03    3
# 11  2018-06-07T11:15:11.091787Z   ar30-03    3
# 12  2018-06-07T11:19:02.216972Z   ar30-03    3
# 13  2018-06-07T11:21:46.383770Z   ar30-03    3
# 14  2018-06-07T11:23:52.175538Z   ar30-03    3
# 15  2018-06-07T11:30:02.425834Z   ar30-03    3
# 16  2018-06-07T11:30:10.800840Z   ar30-03    3
#
# [17 rows x 21 columns]

# %% [markdown]
# ### Create A Summary Sheet
# Now, I want to generate a summary sheet from all of the processed bottle files. This includes loding all of the files into dataframes and appending. The one challenge is if some casts included columns that are unique.

# %%
dirpath = 'C:/Users/areed/Documents/OOI-CGSN/QAQC_Sandbox/Ship_data/Irminger/Irminger-5/Data/CTD/'
btl = pd.DataFrame()
for file in os.listdir(dirpath):
    if '.csv' in file:
        df = pd.read_csv(dirpath+file)
        btl = btl.append(df)
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
os.listdir(dirpath)
# Out:
# ['ar30-03.psa',
#  'ar30-03.xmlcon',
#  'ar30-03001.bl',
#  'ar30-03001.btl',
#  'ar30-03001.csv',
#  'ar30-03001.hdr',
#  'ar30-03001.hex',
#  'ar30-03001.ros',
#  'AR30-03001.XMLCON',
#  'ar30-03002.bl',
#  'ar30-03002.hdr',
#  'ar30-03002.hex',
#  'AR30-03002.XMLCON',
#  'ar30-03002b.bl',
#  'ar30-03002b.btl',
#  'ar30-03002b.csv',
#  'ar30-03002b.hdr',
#  'ar30-03002b.hex',
#  'ar30-03002b.ros',
#  'AR30-03002B.XMLCON',
#  'ar30-03003.bl',
#  'ar30-03003.btl',
#  'ar30-03003.csv',
#  'ar30-03003.hdr',
#  'ar30-03003.hex',
#  'ar30-03003.ros',
#  'AR30-03003.XMLCON',
#  'ar30-03004.bl',
#  'ar30-03004.btl',
#  'ar30-03004.csv',
#  'ar30-03004.hdr',
#  'ar30-03004.hex',
#  'ar30-03004.ros',
#  'AR30-03004.XMLCON',
#  'ar30-03005.bl',
#  'ar30-03005.btl',
#  'ar30-03005.csv',
#  'ar30-03005.hdr',
#  'ar30-03005.hex',
#  'ar30-03005.ros',
#  'AR30-03005.XMLCON',
#  'ar30-03006.bl',
#  'ar30-03006.btl',
#  'ar30-03006.csv',
#  'ar30-03006.hdr',
#  'ar30-03006.ros',
#  'AR30-03006.XMLCON',
#  'ar30-03007.bl',
#  'ar30-03007.btl',
#  'ar30-03007.csv',
#  'ar30-03007.hdr',
#  'ar30-03007.hex',
#  'ar30-03007.ros',
#  'AR30-03007.XMLCON',
#  'ar30-03008.bl',
#  'ar30-03008.btl',
#  'ar30-03008.csv',
#  'ar30-03008.hdr',
#  'ar30-03008.hex',
#  'ar30-03008.ros',
#  'AR30-03008.XMLCON',
#  'ar30-03009.bl',
#  'ar30-03009.btl',
#  'ar30-03009.csv',
#  'ar30-03009.hdr',
#  'ar30-03009.hex',
#  'ar30-03009.ros',
#  'AR30-03009.XMLCON',
#  'ar30-03010.bl',
#  'ar30-03010.btl',
#  'ar30-03010.csv',
#  'ar30-03010.hdr',
#  'ar30-03010.hex',
#  'ar30-03010.ros',
#  'AR30-03010.XMLCON',
#  'ar30-03011.bl',
#  'ar30-03011.btl',
#  'ar30-03011.csv',
#  'ar30-03011.hdr',
#  'ar30-03011.hex',
#  'ar30-03011.ros',
#  'AR30-03011.XMLCON',
#  'ar30-03012.bl',
#  'ar30-03012.btl',
#  'ar30-03012.csv',
#  'ar30-03012.hdr',
#  'ar30-03012.hex',
#  'ar30-03012.ros',
#  'AR30-03012.XMLCON',
#  'ar30-03013.bl',
#  'ar30-03013.btl',
#  'ar30-03013.csv',
#  'ar30-03013.hdr',
#  'ar30-03013.hex',
#  'ar30-03013.ros',
#  'AR30-03013.XMLCON',
#  'ar30-03014.bl',
#  'ar30-03014.btl',
#  'ar30-03014.csv',
#  'ar30-03014.hdr',
#  'ar30-03014.hex',
#  'ar30-03014.ros',
#  'AR30-03014.XMLCON',
#  'ar30-03015.bl',
#  'ar30-03015.btl',
#  'ar30-03015.csv',
#  'ar30-03015.hdr',
#  'ar30-03015.hex',
#  'ar30-03015.ros',
#  'AR30-03015.XMLCON',
#  'ar30-03016.bl',
#  'ar30-03016.btl',
#  'ar30-03016.csv',
#  'ar30-03016.hdr',
#  'ar30-03016.hex',
#  'ar30-03016.ros',
#  'AR30-03016.XMLCON',
#  'ar30-03017.bl',
#  'ar30-03017.btl',
#  'ar30-03017.csv',
#  'ar30-03017.hdr',
#  'ar30-03017.hex',
#  'ar30-03017.ros',
#  'AR30-03017.XMLCON',
#  'ar30-03018.bl',
#  'ar30-03018.btl',
#  'ar30-03018.csv',
#  'ar30-03018.hdr',
#  'ar30-03018.hex',
#  'ar30-03018.ros',
#  'AR30-03018.XMLCON',
#  'ar30-03019.bl',
#  'ar30-03019.btl',
#  'ar30-03019.csv',
#  'ar30-03019.hdr',
#  'ar30-03019.hex',
#  'ar30-03019.ros',
#  'AR30-03019.XMLCON',
#  'ar30-03020.bl',
#  'ar30-03020.btl',
#  'ar30-03020.csv',
#  'ar30-03020.hdr',
#  'ar30-03020.hex',
#  'ar30-03020.ros',
#  'AR30-03020.XMLCON',
#  'ar30-03021.bl',
#  'ar30-03021.btl',
#  'ar30-03021.csv',
#  'ar30-03021.hdr',
#  'ar30-03021.hex',
#  'ar30-03021.ros',
#  'AR30-03021.XMLCON',
#  'ar30-03022.bl',
#  'ar30-03022.btl',
#  'ar30-03022.csv',
#  'ar30-03022.hdr',
#  'ar30-03022.hex',
#  'ar30-03022.ros',
#  'AR30-03022.XMLCON',
#  'ar30-03023.bl',
#  'ar30-03023.btl',
#  'ar30-03023.csv',
#  'ar30-03023.hdr',
#  'ar30-03023.hex',
#  'ar30-03023.ros',
#  'AR30-03023.XMLCON',
#  'Water_sampling_comparison.xlsx']

# %%
btl
# Out:
#     Beam Attenuation, WET Labs C-Star [1/m]  \
# 0                                 19.036789
# 1                                 19.161090
# 2                                 21.422320
# 3                                 26.667423
# 4                                 28.169660
# 5                                 22.205639
# 6                                 22.138271
# 0                                 16.659648
# 1                                 17.789664
# 2                                 17.367361
# 3                                 17.413474
# 4                                 16.954309
# 5                                 17.128353
# 6                                 17.277351
# 0                                 24.113882
# 1                                 55.262000
# 2                                 55.262000
# 3                                 55.262000
# 4                                 55.262000
# 5                                 55.262000
# 6                                 55.262000
# 7                                 55.262000
# 8                                 55.262000
# 9                                 55.262000
# 10                                55.262000
# 11                                55.262000
# 12                                55.262000
# 13                                55.262000
# 14                                55.262000
# 15                                55.262000
# ..                                      ...
# 3                                 55.262000
# 4                                 55.262000
# 5                                 55.262000
# 6                                 55.262000
# 7                                 55.262000
# 8                                 55.262000
# 9                                 55.262000
# 10                                55.262000
# 11                                55.262000
# 12                                55.262000
# 13                                55.262000
# 14                                55.262000
# 15                                55.262000
# 16                                55.262000
# 17                                55.262000
# 18                                55.262000
# 19                                55.262000
# 0                                 17.099398
# 1                                 19.537448
# 2                                 24.165016
# 3                                 55.262000
# 4                                 55.262000
# 5                                 55.262000
# 6                                 55.262000
# 0                                 24.594935
# 1                                 55.262000
# 2                                 22.970531
# 3                                 18.965812
# 4                                 18.949927
# 5                                 21.139523
#
#     Beam Transmission, WET Labs C-Star [%]  Bottles Fired  Cast  \
# 0                                 0.857820            1.0     1
# 1                                 0.831087            2.0     1
# 2                                 0.476894            3.0     1
# 3                                 0.128244            4.0     1
# 4                                 0.137615            5.0     1
# 5                                 0.395238            6.0     1
# 6                                 0.396349            7.0     1
# 0                                 1.555459            1.0  002b
# 1                                 1.171753            2.0  002b
# 2                                 1.301403            3.0  002b
# 3                                 1.288719            4.0  002b
# 4                                 1.442898            5.0  002b
# 5                                 1.382208            6.0  002b
# 6                                 1.331186            7.0  002b
# 0                                 0.241305            1.0     3
# 1                                -0.252421            2.0     3
# 2                                -0.207462            3.0     3
# 3                                -0.046368            4.0     3
# 4                                -0.093530            5.0     3
# 5                                -0.536274            6.0     3
# 6                                -0.809901            7.0     3
# 7                                -0.859861            8.0     3
# 8                                -0.992252            9.0     3
# 9                                -0.955559           10.0     3
# 10                               -0.593641           11.0     3
# 11                               -0.604692           12.0     3
# 12                               -0.672830           13.0     3
# 13                               -0.701805           14.0     3
# 14                               -0.773764           15.0     3
# 15                               -0.749529           16.0     3
# ..                                     ...            ...   ...
# 3                                -0.858478            4.0    21
# 4                                -0.736006            5.0    21
# 5                                -0.836109            6.0    21
# 6                                -0.872810            7.0    21
# 7                                -0.916952            8.0    21
# 8                                -0.906742            9.0    21
# 9                                -0.924135           10.0    21
# 10                               -0.921648           11.0    21
# 11                               -0.931871           12.0    21
# 12                               -0.929937           13.0    21
# 13                               -0.921648           14.0    21
# 14                               -0.924135           15.0    21
# 15                               -0.892412           16.0    21
# 16                               -1.013453           17.0    21
# 17                               -1.013176           18.0    21
# 18                               -0.921365           19.0    21
# 19                               -0.933526           20.0    21
# 0                                 1.391866            1.0    22
# 1                                 0.756608            2.0    22
# 2                                 0.238553            3.0    22
# 3                                -0.039751            4.0    22
# 4                                -0.234759            5.0    22
# 5                                -0.411038            6.0    22
# 6                                -0.403042            7.0    22
# 0                                 0.214566            1.0    23
# 1                                -0.163060            2.0    23
# 2                                 0.321897            3.0    23
# 3                                 0.872709            4.0    23
# 4                                 0.878252            5.0    23
# 5                                 0.506952            6.0    23
#
#     Conductivity [S/m]  Conductivity, 2 [S/m] Cruise ID  \
# 0             3.455169               3.454611   ar30-03
# 1             3.476623               3.476591   ar30-03
# 2             3.505544               3.505613   ar30-03
# 3             3.540467               3.542229   ar30-03
# 4             3.558928               3.558911   ar30-03
# 5             3.559666               3.559626   ar30-03
# 6             3.559819               3.559834   ar30-03
# 0             3.491486               3.491553   ar30-03
# 1             3.496320               3.496352   ar30-03
# 2             3.514970               3.515027   ar30-03
# 3             3.545500               3.546033   ar30-03
# 4             3.553650               3.553698   ar30-03
# 5             3.554467               3.554497   ar30-03
# 6             3.554469               3.554513   ar30-03
# 0             3.137537               3.137507   ar30-03
# 1             3.268464               3.268433   ar30-03
# 2             3.289796               3.289805   ar30-03
# 3             3.274421               3.274428   ar30-03
# 4             3.246366               3.246374   ar30-03
# 5             3.244405               3.244420   ar30-03
# 6             3.242305               3.242309   ar30-03
# 7             3.242139               3.242190   ar30-03
# 8             3.241322               3.241387   ar30-03
# 9             3.259844               3.259899   ar30-03
# 10            3.313183               3.313258   ar30-03
# 11            3.313178               3.313184   ar30-03
# 12            3.367401               3.367666   ar30-03
# 13            3.372497               3.372530   ar30-03
# 14            3.375879               3.375934   ar30-03
# 15            3.378711               3.378790   ar30-03
# ..                 ...                    ...       ...
# 3             3.219127               3.219247   ar30-03
# 4             3.222077               3.222188   ar30-03
# 5             3.223332               3.223437   ar30-03
# 6             3.228067               3.228177   ar30-03
# 7             3.228523               3.228560   ar30-03
# 8             3.243700               3.243770   ar30-03
# 9             3.256794               3.256895   ar30-03
# 10            3.257478               3.257635   ar30-03
# 11            3.270964               3.270828   ar30-03
# 12            3.274597               3.274780   ar30-03
# 13            3.278259               3.278419   ar30-03
# 14            3.284481               3.284834   ar30-03
# 15            3.286609               3.286819   ar30-03
# 16            3.326968               3.327034   ar30-03
# 17            3.401759               3.401885   ar30-03
# 18            3.478238               3.477841   ar30-03
# 19            3.476974               3.477019   ar30-03
# 0             3.321510               3.321724   ar30-03
# 1             3.356513               3.356538   ar30-03
# 2             3.387098               3.387545   ar30-03
# 3             3.490262               3.490368   ar30-03
# 4             3.492968               3.493182   ar30-03
# 5             3.494011               3.494038   ar30-03
# 17  2018-06-19T19:25:05.628035Z              15.737845   0.0
# 18  2018-06-19T19:26:51.253120Z               4.225361   0.0
# 19  2018-06-19T19:27:00.628127Z               4.226144   0.0
# 0   2018-06-22T13:54:47.000316Z             153.808247   0.0
# 1   2018-06-22T13:58:02.167139Z             100.607227   0.0
# 2   2018-06-22T14:01:15.625627Z              40.820278   0.0
# 3   2018-06-22T14:03:11.667387Z              25.349412   0.0
# 4   2018-06-22T14:05:05.000811Z              15.724948   0.0
# 5   2018-06-22T14:06:38.125885Z               4.022433   0.0
# 6   2018-06-22T14:06:51.875896Z               4.706505   0.0
# 0   2018-06-22T20:13:47.541992Z             152.738258   0.0
# 1   2018-06-22T20:16:19.000447Z             102.609876   0.0
# 2   2018-06-22T20:19:23.917261Z              42.657495   0.0
# 3   2018-06-22T20:21:08.209011Z              25.621227   0.0
# 4   2018-06-22T20:22:43.250754Z              17.541814   0.0
# 5   2018-06-22T20:24:37.375845Z               2.934155   0.0
#
#                 ...                Oxygen raw, SBE 43 [V]  \
# 0               ...                                   NaN
# 1               ...                                   NaN
# 2               ...                                   NaN
# 3               ...                                   NaN
# 4               ...                                   NaN
# 5               ...                                   NaN
# 6               ...                                   NaN
# 0               ...                                   NaN
# 1               ...                                   NaN
# 2               ...                                   NaN
# 3               ...                                   NaN
# 4               ...                                   NaN
# 5               ...                                   NaN
# 6               ...                                   NaN
# 0               ...                                   NaN
# 1               ...                                   NaN
# 2               ...                                   NaN
# 3               ...                                   NaN
# 4               ...                                   NaN
# 5               ...                                   NaN
# 6               ...                                   NaN
# 7               ...                                   NaN
# 8               ...                                   NaN
# 9               ...                                   NaN
# 10              ...                                   NaN
# 11              ...                                   NaN
# 12              ...                                   NaN
# 13              ...                                   NaN
# 14              ...                                   NaN
# 15              ...                                   NaN
# ..              ...                                   ...
# 3               ...                                   NaN
# 4               ...                                   NaN
# 5               ...                                   NaN
# 6               ...                                   NaN
# 7               ...                                   NaN
# 8               ...                                   NaN
# 9               ...                                   NaN
# 10              ...                                   NaN
# 11              ...                                   NaN
# 12              ...                                   NaN
# 13              ...                                   NaN
# 14              ...                                   NaN
# 15              ...                                   NaN
# 16              ...                                   NaN
# 17              ...                                   NaN
# 18              ...                                   NaN
# 19              ...                                   NaN
# 0               ...                                   NaN
# 1               ...                                   NaN
# 2               ...                                   NaN
# 3               ...                                   NaN
# 4               ...                                   NaN
# 5               ...                                   NaN
# 6               ...                                   NaN
# 0               ...                                   NaN
# 1               ...                                   NaN
# 2               ...                                   NaN
# 3               ...                                   NaN
# 4               ...                                   NaN
# 5               ...                                   NaN
#
#     Oxygen, SBE 43 [ml/l]  Pressure, Digiquartz [db]  SPAR/Surface Irradiance  \
# 0                6.285522                 148.209113                      NaN
# 1                6.398124                 105.772670                      NaN
# 2                6.660419                  40.562536                      NaN
# 3                7.070651                  23.395247                      NaN
# 4                7.059086                  15.492526                      NaN
# 5                7.072604                   2.739423                      NaN
# 6                7.073497                   2.971546                      NaN
# 0                6.273453                 155.359567                      NaN
# 1                6.412878                  99.927062                      NaN
# 2                6.566302                  39.451670                      NaN
# 3                6.924348                  26.291928                      NaN
# 4                7.034376                  14.528113                      NaN
# 5                7.030471                   4.687041                      NaN
# 6                7.037107                   4.574227                      NaN
# 0                6.562714                2998.401887                      NaN
# 1                6.029555                2540.190990                      NaN
# 2                5.951516                2029.040691                      NaN
# 3                6.223611                1623.636144                      NaN
# 4                6.549161                1317.683866                      NaN
# 5                6.550929                1014.467856                      NaN
# 6                6.554013                 812.846619                      NaN
# 7                6.549424                 609.473485                      NaN
# 8                6.548033                 407.482876                      NaN
# 9                6.461930                 205.654742                      NaN
# 10               6.679131                 105.380320                      NaN
# 11               6.680360                 105.551763                      NaN
# 12               6.853102                  44.902835                      NaN
# 13               6.928089                  25.294577                      NaN
# 14               6.922264                  15.271845                      NaN
# 15               6.935088                   4.701845                      NaN
# ..                    ...                        ...                      ...
# 3                6.501774                 710.622258                      NaN
# 4                6.499490                 609.233474                      NaN
# 5                6.495731                 507.959701                      NaN
# 6                6.472986                 406.446371                      NaN
# 7                6.492447                 306.348402                      NaN
# 8                6.454174                 205.436629                      NaN
# 9                6.706500                 151.433371                      NaN
# 10               6.712557                 121.438629                      NaN
# 11               6.677496                 101.626381                      NaN
# 12               6.686953                  91.693784                      NaN
# 13               6.675277                  81.514660                      NaN
# 14               6.656419                  61.162680                      NaN
# 15               6.661165                  51.398010                      NaN
# 16               6.706435                  30.877505                      NaN
# 17               7.298974                  15.888082                      NaN
# 18               7.431012                   4.265660                      NaN
# 19               7.438663                   4.266536                      NaN
# 0                6.305508                 155.350948                      NaN
# 1                6.493134                 101.602969                      NaN
# 2                6.713552                  41.218309                      NaN
# 3                6.853186                  25.595691                      NaN
# 4                6.861938                  15.877309                      NaN
# 5                6.876738                   4.061351                      NaN
# 6                6.871160                   4.752031                      NaN
# 0                6.166557                 154.274526                      NaN
# 1                6.550141                 103.629268                      NaN
# 2                6.751909                  43.074938                      NaN
# 3                6.750729                  25.870773                      NaN
# 4                6.808640                  17.712351                      NaN
# 5                6.879264                   2.962639                      NaN
#
#     Salinity, Practical [PSU]  Salinity, Practical, 2 [PSU]    Scan Count  \
# 0                   34.951198                     34.951134   4237.711724
# 1                   34.955305                     34.955442   4521.295284
# 2                   34.964652                     34.964534   4800.753841
# 3                   34.973422                     34.968558   4929.795610
# 4                   34.966438                     34.966319   5007.462339
# 5                   34.966416                     34.965722   5129.920771
# 6                   34.966478                     34.966449   5137.962444
# 0                   34.976795                     34.976764    731.333918
# 1                   34.968881                     34.969022    915.875733
# 2                   34.973564                     34.973786   1106.000885
# 3                   34.974363                     34.974756   1233.750987
# 4                   34.974270                     34.974377   1340.542739
# 5                   34.974008                     34.974341   1419.626136
# 6                   34.974097                     34.974362   1427.626142
# 0                   34.884199                     34.881792   3692.419621
# 1                   34.926077                     34.924311   4511.920276
# 2                   34.939911                     34.938716   5581.587799
# 3                   34.896610                     34.895913   6364.338425
# 4                   34.862978                     34.862626   7026.713955
# 5                   34.876921                     34.876723   7689.631152
# 6                   34.883482                     34.883456   8389.923379
# 7                   34.890213                     34.890345   8946.215490
# 8                   34.888293                     34.888597   9504.132603
# 15                     4.430547                        4.431448
# 16                     4.896071                        4.895122
# 17                     5.748815                        5.746361
# 18                     6.593992                        6.588362
# 19                     6.579360                        6.578839
# 0                      4.763080                        4.763169
# 1                      5.158651                        5.157162
# 2                      5.551194                        5.555459
# 3                      6.714384                        6.714854
# 4                      6.748046                        6.749421
# 5                      6.765307                        6.764315
# 6                      6.764697                        6.764372
# 0                      5.159049                        5.157173
# 1                      5.189036                        5.187429
# 2                      6.909669                        6.931885
# 3                      7.255239                        7.250530
# 4                      7.277710                        7.277826
# 5                      7.282156                        7.281831
#
#     Turbidity, WET Labs ECO [NTU]
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# ..                            ...
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                            NaN
# 19                            NaN
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
#
# [340 rows x 25 columns]

# %%
btl.dropna(subset=['Turbidity, WET Labs ECO [NTU]'])
# Out:
#     Beam Attenuation, WET Labs C-Star [1/m]  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
#
#     Beam Transmission, WET Labs C-Star [%]  Bottles Fired Cast  \
# 0                                      NaN            1.0    6
# 1                                      NaN            2.0    6
# 2                                      NaN            3.0    6
# 3                                      NaN            4.0    6
# 4                                      NaN            5.0    6
# 5                                      NaN            6.0    6
# 6                                      NaN            7.0    6
# 7                                      NaN            8.0    6
# 8                                      NaN            9.0    6
# 9                                      NaN           10.0    6
# 10                                     NaN           11.0    6
# 11                                     NaN           12.0    6
# 12                                     NaN           13.0    6
# 13                                     NaN           14.0    6
# 14                                     NaN           15.0    6
# 15                                     NaN           16.0    6
# 16                                     NaN           17.0    6
# 17                                     NaN           18.0    6
# 18                                     NaN           19.0    6
# 19                                     NaN           20.0    6
# 20                                     NaN           21.0    6
# 21                                     NaN           22.0    6
# 22                                     NaN           23.0    6
# 23                                     NaN           24.0    6
#
#     Conductivity [S/m]  Conductivity, 2 [S/m] Cruise ID  \
# 0             3.139994               3.139922   ar30-03
# 1             3.155050               3.155097   ar30-03
# 2             3.255287               3.255307   ar30-03
# 3             3.285758               3.285768   ar30-03
# 4             3.266032               3.266057   ar30-03
# 5             3.260472               3.260503   ar30-03
# 6             3.261812               3.261873   ar30-03
# 7             3.259531               3.259582   ar30-03
# 8             3.278960               3.278960   ar30-03
# 9             3.316194               3.316193   ar30-03
# 10            3.316962               3.317117   ar30-03
# 11            3.324043               3.324202   ar30-03
# 12            3.323861               3.323837   ar30-03
# 9                     NaN                 405.744367               827.895714
# 10                    NaN                 306.984224               818.127755
# 11                    NaN                 204.671592               773.916327
# 12                    NaN                 203.609000               812.256735
# 13                    NaN                 176.357776               782.721429
# 14                    NaN                 151.803265               788.595918
# 15                    NaN                 151.260694               778.455306
# 16                    NaN                 101.242122               818.448980
# 17                    NaN                 101.898041               811.979592
# 18                    NaN                  51.376184               748.556327
# 19                    NaN                  51.705653               740.482245
# 20                    NaN                  20.613490               783.453878
# 21                    NaN                  20.655755               774.968571
# 22                    NaN                  10.093959               813.630816
# 23                    NaN                   5.349673               809.044898
#
#     Salinity, Practical [PSU]  Salinity, Practical, 2 [PSU]   Scan Count  \
# 0                   34.886451                           NaN  3003.960736
# 1                   34.890100                           NaN  3345.627676
# 2                   34.908600                           NaN  4846.170544
# 3                   34.922733                           NaN  5242.337527
# 4                   34.880163                           NaN  5701.671228
# 5                   34.883831                           NaN  6156.338258
# 6                   34.893990                           NaN  6503.796870
# 7                   34.895982                           NaN  6810.672115
# 8                   34.905033                           NaN  7144.422382
# 9                   34.913984                           NaN  7488.505991
# 10                  34.890414                           NaN  7708.839500
# 11                  34.883418                           NaN  7916.464667
# 12                  34.883186                           NaN  7932.589679
# 13                  34.889178                           NaN  8067.714788
# 14                  34.909629                           NaN  8199.839893
# 15                  34.909853                           NaN  8214.048238
# 16                  34.915667                           NaN  8365.965026
# 17                  34.915584                           NaN  8373.423365
# 18                  34.896188                           NaN  8545.590170
# 19                  34.894584                           NaN  8553.881843
# 20                  34.904147                           NaN  8682.798613
# 21                  34.904035                           NaN  8691.590287
# 22                  34.877200                           NaN  8784.173694
# 23                  34.877816                           NaN  8852.090415
#
#     Temperature [ITS-90, deg C]  Temperature, 2 [ITS-90, deg C]  \
# 0                      1.513251                        1.513116
# 1                      1.747959                        1.749167
# 2                      3.055310                        3.055708
# 3                      3.524971                        3.525088
# 4                      3.480692                        3.480645
# 5                      3.561078                        3.560833
# 6                      3.666202                        3.666147
# 7                      3.735627                        3.735445
# 8                      4.045600                        4.044631
# 9                      4.552031                        4.550992
# 10                     4.632420                        4.632969
# 11                     4.769208                        4.769737
# 12                     4.767947                        4.766404
# 13                     4.825139                        4.824933
# 14                     5.069849                        5.069759
# 15                     5.071567                        5.071022
# 16                     5.318855                        5.318706
# 17                     5.318933                        5.318943
# 18                     5.634786                        5.634580
# 19                     5.635184                        5.634904
# 20                     5.791686                        5.791173
# 21                     5.794498                        5.794049
# 22                     5.927080                        5.926829
# 23                     5.927569                        5.927478
#
#     Turbidity, WET Labs ECO [NTU]
# 0                        0.406800
# 1                        0.362900
# 2                        0.360500
# 3                        0.356400
# 4                        0.358500
# 5                        0.361900
# 6                        0.365596
# 7                        0.370053
# 8                        0.376100
# 9                        0.389100
# 10                       0.396496
# 11                       0.392000
# 12                       0.392100
# 13                       0.391698
# 14                       0.396198
# 15                       0.397786
# 16                       0.433749
# 17                       0.573210
# 18                       0.494033
# 19                       0.483694
# 20                       0.578392
# 21                       0.577169
# 22                       0.597408
# 23                       0.680947
#
# [24 rows x 25 columns]
